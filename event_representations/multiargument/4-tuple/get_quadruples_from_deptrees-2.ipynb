# %% [markdown]
# # Get relgrams(relational triples, <subj, verb, obj>) from the deptrees generated from goals and step headlines.
# 01.05.2023

# %%
import dill as pickle
from collections import defaultdict
from tqdm import tqdm

# %%
# Get tuples from goals.
# For loading the deptrees.
deptree_path = "/mount/studenten/arbeitsdaten-studenten1/shencg/BA/V2/event_representations/relational/dep_parsing/"
# For loading fid2goal and sid2step.
relgram_path = "/mount/studenten/arbeitsdaten-studenten1/shencg/BA/V2/event_representations/relational/relgram/"

# Load fid2goal.
fid2goal = pickle.load(open(relgram_path + 'fid2goal.p', 'rb'))
# Load deptrees of goals.
goal_parses = pickle.load(open(deptree_path + 'goal_parsing/goal_parses.p', 'rb'))

# %% [markdown]
# ## Goal.

# %%
def get_subtree(deptree, arc2dep:dict, idx_node:int):
    """
    Get the subtree of a node in a dependency tree in form of a python dictionary.
    
    @param deptree:supar.utils.Dataset  Dependency tree object generated by supar.
    @param arc2dep:dict A mapping from arc to a [word, idx, rel]-list representing 
                        the whole deptree of a sentence.
    @param idx_node:str  Idex of the word corresponding to the node in the deptree.
    @returns subtree:dict  A mapping from arc to a [word, idx, rel]-list representing 
                           the subtree of the passed node.
    """
    
    if idx_node in range(1, len(deptree.texts)+1):
        subtree = defaultdict(list)
        if idx_node in arc2dep:
            subtree[idx_node] = arc2dep[idx_node]
            subtree_words = [item[0] for item in arc2dep[idx_node]]
            subtree_idxs = [item[1] for item in arc2dep[idx_node]]
            for idx_subtree_node in subtree_idxs:
                subtree.update(get_subtree(deptree, arc2dep, idx_subtree_node))
        subtree = dict(sorted(subtree.items()))
        return subtree
    else:
        raise ValueError("The word is not in any node of the deptree! Check your argument!")

# %%
def get_quadruple(deptree):
    """
    Get <subj, verb, obj, prep_phrase>-tuples ('quadruple') from the dependency trees(deptree).
    
    @param deptree: supar.utils.Dataset  Dependency tree object generated by supar.
    @returns tuple: list[str]  The quadruple extracted from each deptree.
    """
    
    # Create a mapping from the arcs of a deptree to the [word, index, relation] of the deptree.
    arc2dep = defaultdict(list)
    for idx, w, arc, rel in zip(range(1, len(deptree.texts)+1), deptree.texts, deptree.arcs, deptree.rels):
        tmp = []
        if [w, idx, rel] not in arc2dep[arc]:
            tmp.append([w, idx, rel])
        arc2dep[arc] += tmp
    arc2dep = dict(sorted(arc2dep.items()))
    
    # Initialize 4-tuple with the root word, i.e. the predicate verb.
    root = arc2dep[0][0][0]
    # Get the index of the root word in the sentence.
    idx_root = arc2dep[0][0][1]
    
    quadruple = [root]
    indices = [[idx_root-2]]
    
    
    idx_dobj = None
    dobj = ""
    prep = ""
    idx_pobj = None
    for arc, deps in get_subtree(deptree, arc2dep, idx_root).items():
        for dep in deps:
            if dep[2] == 'dobj':
                idx_dobj = dep[1]
                if arc == idx_root:
                    dobj = dobj + dep[0] + ' '
#                     indices.append([idx_dobj-2])
                    if len(indices) == 1:
                        indices.append([idx_dobj-2])
                    elif len(indices) > 1:
                        indices[-1].append(idx_dobj-2)
                    else:
                        break
            if dep[2] == 'prep':
                idx_prep = dep[1]
                prep = prep + ' ' + dep[0]
                prep.strip()
                indices.append([idx_prep-2])
            if dep[2] == 'pobj':
                idx_pobj = dep[1]
                prep = prep + ' ' + dep[0]
                prep.strip()
                indices[-1] += [idx_pobj-2]
                
                
        # Check if the predicate consists of multiple verbs, e.g. "make and use", and 
        # if the direct object and the object of the prep. phrase is a phrase consisting of mulitple tokens, 
        # e.g. "heel pain and plantar fasciitis".
        if len(deps) > 1:
            for dep1, dep2 in zip(deps[:-1], deps[1:]):
                if dep1[2] == 'cc' and dep2[2] == 'conj':
                    # If the predicate consists of multiple verbs
                    if arc == idx_root:
                        quadruple[0] = quadruple[0] + ' ' + dep1[0] + ' ' + dep2[0]
                        # Add the indices of the tokens into the internal list for the idx_root.
                        indices[0] += [dep1[1]-2, dep2[1]-2]
                    # If the direct object consists of multiple tokens
                    if arc == idx_dobj:
                        dobj = dobj + ' ' + dep1[0] + ' ' + dep2[0]
                        # Add the indices of the tokens into the internal list for the idx_dobj.
                        if len(indices) > 1:
                            indices[1] += [dep1[1]-2, dep2[1]-2]
                    # If the object of the prep. phrase consists of multiple tokens
                    if arc == idx_pobj:
                        prep = prep + ' ' + dep1[0] + ' ' + dep2[0]
                        # Add the indices of the tokens into the internal list for the idx_pobj.
                        if len(indices) > 1:
                            indices[-1] += [dep1[1]-2, dep2[1]-2]
                        
    # Remove the whitespace at the end of dobj, especially for the dobj with multiple words.
    dobj = dobj.strip()
    # Append dobj and prep to quadruple and add subj('person') at the beginning of quadruple.
    quadruple.append(dobj)
    quadruple.append(prep)
    quadruple = ['<|startoftext|>'] + quadruple
    indices = [[0]] + indices
    
    # Delete whitespace at the beginning of each item in quadruple.
    quadruple = [item[1:] if item.startswith(' ') else item for item in quadruple]
    
    # Unify the quadruple length by padding with a '[PAD]' token, so that the BERT-embeddings will be of the same length.
#     quadruple = ['[PAD]' if item == '' else item for item in quadruple]
    for idx, item in enumerate(quadruple):
        if item == "":
            quadruple[idx] = "[PAD]"
#             indices = indices + [[-1]]
            indices.insert(idx, [-1])
        else:
            item = item
            
    return [quadruple, indices]

# %% [markdown]
# ### Start Test.

# %%
list(fid2goal.items())[1]
# Out:
# ('10000832', ('how', 'to', 'plant', 'lavender', 'in', 'pots'))

# %%
deptree = list(fid2parses.items())[1][1].sentences[0]
deptree
# Out:
# 1	how	_	_	_	_	3	advmod	_	_
# 2	to	_	_	_	_	3	aux	_	_
# 3	plant	_	_	_	_	0	root	_	_
# 4	lavender	_	_	_	_	3	dobj	_	_
# 5	in	_	_	_	_	3	prep	_	_
# 6	pots	_	_	_	_	5	pobj	_	_

# %%
result = get_quadruple(deptree)
result
# Out:
# [['<|startoftext|>', 'plant', 'lavender', 'in pots'], [[0], [1], [2], [3, 4]]]

# %% [markdown]
# ### End Test.

# %%
for i, w in enumerate(["<|startoftext|>"] + list(fid2goal['10058376'][2:])):
    print(i, w)
# Out:
# 0 <|startoftext|>
# 1 fly
# 2 to
# 3 new
# 4 zealand
# 5 for
# 6 cheap

# %%
# Create a mapping from file_id to quadruples extracted from that goal.
fid2quadruple = dict()
for fid in tqdm(goal_parses):
    deptree = goal_parses[fid].sentences[0]
    if fid not in fid2quadruple:
        fid2quadruple[fid] = get_quadruple(deptree)
        
for fid, values in list(fid2quadruple.items()):
    print("BEFORE:", fid, values)
    values[1] = [item for sublist in values[1] for item in sublist]
    print("AFTER:", fid, values, "\n")
        
# for fid, values in list(fid2quadruple.items()):
#     if len(values[1]) == 1 and type(values[1][0]) == list:
# #         print("BEFORE:", fid, values)
#         values[1] = values[1][0]
#         for word in values[0]:
#             if word == '[PAD]':
# #                 values[1][values[0].index(word)] = -1
#                 pad_idx = values[0].index(word)
#                 l1, l2 = values[1][1:pad_idx+1], values[1][pad_idx+1:]
#                 print("l1:", l1, "l2:", l2)
#                 values[1] = l1 + [-1] + l2
# #         print("AFTER:", fid, values, "\n")
# Out:
#   0%|                                                                                                   | 0/53186 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 3>()
#       4     deptree = goal_parses[fid].sentences[0]
#       5     if fid not in fid2quadruple:
# ----> 6         fid2quadruple[fid] = get_quadruple(deptree)
#       8 for fid, values in list(fid2quadruple.items()):
#       9     print("BEFORE:", fid, values)
#
# NameError: name 'get_quadruple' is not defined

# %%
for i, values in list(fid2quadruple.items()):
    items = " ".join(values[0]).split()
    if len(items) != len(values[1]):
        print(i, values)
        l1, l2 = values[0][:2], values[0][2:]
        l3, l4 = values[1][:2], values[1][2:]
        for i, item in enumerate(l2):
            if item != '[PAD]':
                l2[i] = '[PAD]'
        l4 = [-1, -1]
        values[0] = l1 + l2
        values[1] = l3 + l4
        print("l1:", l1, "l2:", l2, "l3:", l3, "l4:", l4)
        print("AFTER:", i, values, '\n')
# Out:
# 11720166 [['<|startoftext|>', 'stop', 'and cheeks', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'stop'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'stop', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 1773985 [['<|startoftext|>', 'react', 'or cat', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'react'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'react', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 1797701 [['<|startoftext|>', 'girls', 'and routine', '[PAD]'], [0, 9, -1]]
# l1: ['<|startoftext|>', 'girls'] l2: ['[PAD]', '[PAD]'] l3: [0, 9] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'girls', '[PAD]', '[PAD]'], [0, 9, -1, -1]]
#
# 18294 [['<|startoftext|>', 'know', 'or her', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'know'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'know', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 389518 [['<|startoftext|>', 'get', 'and fruits', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'get'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'get', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 469743 [['<|startoftext|>', 'sleep', '[PAD]', 'kids and teens'], [0, 1, 5, -1]]
# l1: ['<|startoftext|>', 'sleep'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'sleep', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 5287325 [['<|startoftext|>', 'know', 'or letter', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'know'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'know', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 5348972 [['<|startoftext|>', 'eat', 'and diabetes', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'eat'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'eat', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 540405 [['<|startoftext|>', 'stop', 'and phenomena', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'stop'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'stop', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 5553410 [['<|startoftext|>', 'get', 'and vegetables', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'get'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'get', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 854528 [['<|startoftext|>', 'decide', 'or processor', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'decide'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'decide', '[PAD]', '[PAD]'], [0, 1, -1, -1]]

# %%
for i, values in list(fid2quadruple.items()):
    items = " ".join(values[0]).split()
    assert len(items) == len(values[1])

# %%
print(fid2goal['11720166'])
print(fid2quadruple['11720166'])
# Out:
# ('how', 'to', 'stop', 'biting', 'your', 'lips', 'and', 'cheeks')
# [['<|startoftext|>', 'stop', '[PAD]', '[PAD]'], [0, 1, -1, -1]]

# %%
print(fid2goal['469743'])
print(fid2quadruple['469743'])
# Out:
# ('how', 'to', 'sleep', 'longer', '(', 'for', 'kids', 'and', 'teens', ')')
# [['<|startoftext|>', 'sleep', '[PAD]', '[PAD]'], [0, 1, -1, -1]]

# %%
# # Write fid2quadruple to fid2quadruple.p file.
# with open('fid2quadruple.p', 'wb') as file:
#     pickle.dump(fid2quadruple, file)

# %% [markdown]
# ## Step Headline.
# Since step headlines do not start with "how to", the indices do not need to be -2. Overwrite the get_quadruple() function.

# %%
def get_quadruple(deptree):
    """
    Get <subj, verb, obj, prep_phrase>-tuples ('quadruple') from the dependency trees(deptree).
    
    @param deptree: supar.utils.Dataset  Dependency tree object generated by supar.
    @returns tuple: list[str]  The quadruple extracted from each deptree.
    """
    
    # Create a mapping from the arcs of a deptree to the [word, index, relation] of the deptree.
    arc2dep = defaultdict(list)
    for idx, w, arc, rel in zip(range(1, len(deptree.texts)+1), deptree.texts, deptree.arcs, deptree.rels):
        tmp = []
        if [w, idx, rel] not in arc2dep[arc]:
            tmp.append([w, idx, rel])
        arc2dep[arc] += tmp
    arc2dep = dict(sorted(arc2dep.items()))
    
    # Initialize 4-tuple with the root word, i.e. the predicate verb.
    root = arc2dep[0][0][0]
    # Get the index of the root word in the sentence.
    idx_root = arc2dep[0][0][1]
    
    quadruple = [root]
    indices = [[idx_root]]
    
    
    idx_dobj = None
    dobj = ""
    prep = ""
    idx_pobj = None
    for arc, deps in get_subtree(deptree, arc2dep, idx_root).items():
        for dep in deps:
            if dep[2] == 'dobj':
                idx_dobj = dep[1]
                if arc == idx_root:
                    dobj = dobj + dep[0] + ' '
#                     indices.append([idx_dobj])
                    if len(indices) == 1:
                        indices.append([idx_dobj])
                    elif len(indices) > 1:
                        indices[-1].append(idx_dobj)
                    else:
                        break
            if dep[2] == 'prep':
                idx_prep = dep[1]
                prep = prep + ' ' + dep[0]
                prep.strip()
                indices.append([idx_prep])
            if dep[2] == 'pobj':
                idx_pobj = dep[1]
                prep = prep + ' ' + dep[0]
                prep.strip()
                indices[-1] += [idx_pobj]
                
        # Check if the predicate consists of multiple verbs, e.g. "make and use", and 
        # if the direct object and the object of the prep. phrase is a phrase consisting of mulitple tokens, 
        # e.g. "heel pain and plantar fasciitis".
        if len(deps) > 1:
            for dep1, dep2 in zip(deps[:-1], deps[1:]):
                if dep1[2] == 'cc' and dep2[2] == 'conj':
                    # If the predicate consists of multiple verbs
                    if arc == idx_root:
                        quadruple[0] = quadruple[0] + ' ' + dep1[0] + ' ' + dep2[0]
                        # Add the indices of the tokens into the internal list for the idx_root.
                        indices[0] += [dep1[1], dep2[1]]
                    # If the direct object consists of multiple tokens
                    if arc == idx_dobj:
                        dobj = dobj + ' ' + dep1[0] + ' ' + dep2[0]
                        # Add the indices of the tokens into the internal list for the idx_dobj.
                        if len(indices) > 1:
                            indices[1] += [dep1[1], dep2[1]]
                    # If the object of the prep. phrase consists of multiple tokens
                    if arc == idx_pobj:
                        prep = prep + ' ' + dep1[0] + ' ' + dep2[0]
                        # Add the indices of the tokens into the internal list for the idx_pobj.
                        if len(indices) > 1:
                            indices[-1] += [dep1[1], dep2[1]]
                        
    # Remove the whitespace at the end of dobj, especially for the dobj with multiple words.
    dobj = dobj.strip()
    # Append dobj and prep to quadruple and add subj('person') at the beginning of quadruple.
    quadruple.append(dobj)
    quadruple.append(prep)
    quadruple = ['<|startoftext|>'] + quadruple
    indices = [[0]] + indices
    
    # Delete whitespace at the beginning of each item in quadruple.
#     quadruple = [item[1:] if item.startswith(' ') else item for item in quadruple]
    for idx, item in enumerate(quadruple):
        if item == "":
            quadruple[idx] = "[PAD]"
#             indices = indices + [[-1]]
            indices.insert(idx, [-1])
        else:
            item = item
    
    # Unify the quadruple length by padding with a '[PAD]' token, so that the BERT-embeddings will be of the same length.
#     quadruple = ['[PAD]' if item == '' else item for item in quadruple]
    for idx, item in enumerate(quadruple):
        if item == "":
            quadruple[idx] = "[PAD]"
#             indices = indices + [[-1]]
            indices.insert(idx, [-1])
        else:
            item = item
            
    return [quadruple, indices]

# %%
# Load sid2step
sid2step = pickle.load(open(relgram_path + "sid2step.p", "rb"))
print(len(sid2step))
sid2step
# Out:
# 772221
# {'10000798_0_0': ('find',
#   'a',
#   'door',
#   'to',
#   'hang',
#   'your',
#   'ironing',
#   'board',
#   '.'),
#  '10000798_0_1': ('ensure',
#   'the',
#   'board',
#   'will',
#   'fit',
#   'on',
#   'the',
#   'back',
#   'of',
#   'the',
#   'chosen',
#   'door',
#   '.'),
#  '10000798_0_2': ('buy',
#   'a',
#   'hanger',
#   'with',
#   '2',
#   'hooks',
#   'for',
#   'a',
#   'board',
#   'with',
#   'a',
#   't',
#   '-',
#   'shaped',
#   'base',
#   '.'),
#  '10000798_0_3': ('choose',
#   'bendable',
#   'hooks',
#   'for',
#   'a',
#   'board',
#   'with',
#   'a',
#   'u-',
#   'or',
#   'v-shaped',
#   'base',
#   '.'),
#  '10000798_0_4': ('place',
#   'the',
#   'ironing',
#   'board',
#   'hanger',
#   'over',
#   'the',
#   'door',
#   '.'),
#  '10000798_0_5': ('hang',
#   'your',
#   'ironing',
#   'board',
#   'on',
#   'the',
#   'hanger',
#   '.'),
#  '10000798_1_0': ('choose',
#   'a',
#   'load',
#   '-',
#   'bearing',
#   'wall',
#   'to',
#   'hang',
#   'the',
#   'ironing',
#   'board',
#   '.'),
#  '10000798_1_1': ('confirm',
#   'that',
#   'the',
#   'board',
#   'will',
#   'fit',
#   'your',
#   'chosen',
#   'wall',
#   '.'),
#  '10000798_1_2': ('mark',
#   'the',
#   'wall',
#   'where',
#   'the',
#   'top',
#   'ironing',
#   'board',
#   'base',
#   'will',
#   'rest',
#   '.'),
#  '10000798_1_3': ('choose', 'your', 'coat', 'hooks', '.'),
#  '10000798_1_4': ('install', 'the', 'coat', 'hooks', '.'),
#  '10000798_1_5': ('hang',
#   'your',
#   'ironing',
#   'board',
#   'on',
#   'the',
#   'installed',
#   'hooks',
#   '.'),
#  '10000832_0_0': ('select',
#   'a',
#   'variety',
#   'of',
#   'lavender',
#   'that',
#   'suits',
#   'your',
#   'climate',
#   'and',
#   'space',
#   'best',
#   '.'),
#  '10000832_0_1': ('look', 'for', 'large', 'pots', '.'),
#  '10000832_0_2': ('fill',
#   'the',
#   'bottom',
#   '1',
#   '-',
#   '2',
#   'inches',
#   'of',
#   'your',
#   'pot',
#   'with',
#   'the',
#   'packing',
#   'peanuts',
#   'or',
#   'gravel',
#   '.'),
#  '10000832_0_3': ('pour',
#   'some',
#   'of',
#   'your',
#   'potting',
#   'mix',
#   'into',
#   'your',
#   'pot',
#   '.'),
#  '10000832_1_0': ('remove',
#   'the',
#   'lavender',
#   'plant',
#   'from',
#   'its',
#   'current',
#   'pot',
#   '.'),
#  '10000832_1_1': ('place',
#   'the',
#   'lavender',
#   'plant',
#   'in',
#   'the',
#   'center',
#   'of',
#   'the',
#   'pot',
#   '.'),
#  '10000832_1_2': ('fill',
#   'the',
#   'rest',
#   'of',
#   'the',
#   'pot',
#   'with',
#   'your',
#   'potting',
#   'mix',
#   '.'),
#  '10000832_1_3': ('spread',
#   'a',
#   'half',
#   'cup',
#   'timed',
#   '-',
#   'release',
#   'fertilizer',
#   'over',
#   'your',
#   'potting',
#   'soil',
#   '.'),
#  '10000832_1_4': ('mulch', 'your', 'lavender', 'plant', '.'),
#  '10000832_2_0': ('drench', 'your', 'plant', 'in', 'water', '.'),
#  '10000832_2_1': ('place',
#   'pots',
#   'where',
#   'they',
#   'will',
#   'get',
#   'at',
#   'least',
#   '6',
#   'to',
#   '8',
#   'hours',
#   'of',
#   'sunlight',
#   '.'),
#  '10000832_2_2': ('store',
#   'your',
#   'potted',
#   'lavender',
#   'plants',
#   'in',
#   'a',
#   'garage',
#   'or',
#   'indoors',
#   'during',
#   'the',
#   'winter',
#   'to',
#   'protect',
#   'them',
#   '.'),
#  '10000832_2_3': ('prune', 'your', 'lavender', 'plants', '.'),
#  '10002000_0_0': ('use',
#   'proximity',
#   'to',
#   'attempt',
#   'to',
#   'quiet',
#   'the',
#   'student',
#   'first',
#   '.'),
#  '10002000_0_1': ('keep',
#   'your',
#   'tone',
#   'professional',
#   'when',
#   'addressing',
#   'the',
#   'talkative',
#   'student',
#   '.'),
#  '10002000_0_2': ('call',
#   'the',
#   'name',
#   '(s',
#   ')',
#   'of',
#   'the',
#   'student',
#   'or',
#   'students',
#   'who',
#   'are',
#   'talking',
#   '.'),
#  '10002000_0_3': ('pause',
#   'to',
#   'signal',
#   'that',
#   'you',
#   'need',
#   'their',
#   'attention',
#   '.'),
#  '10002000_0_4': ('redirect',
#   'the',
#   'student',
#   'to',
#   'the',
#   'desired',
#   'behavior',
#   '.'),
#  '10002000_0_5': ('say', 'thank', 'you', 'and', 'move', 'on', '.'),
#  '10002000_0_6': ('give',
#   'the',
#   'student',
#   'a',
#   'warning',
#   'if',
#   'they',
#   'continue',
#   '.'),
#  '10002000_0_7': ('move',
#   'the',
#   'student',
#   '’s',
#   'seat',
#   'if',
#   'the',
#   'issue',
#   'persists',
#   '.'),
#  '10002000_0_8': ('speak',
#   'to',
#   'the',
#   'talkative',
#   'student',
#   'privately',
#   'to',
#   'find',
#   'a',
#   'solution',
#   '.'),
#  '10002000_0_9': ('call',
#   'the',
#   'student',
#   '’s',
#   'parent',
#   'or',
#   'guardian',
#   'if',
#   'necessary',
#   '.'),
#  '10002000_1_0': ('talk', 'to', 'the', 'student', 'in', 'private', '.'),
#  '10002000_1_1': ('ask',
#   'the',
#   'student',
#   'for',
#   'suggestions',
#   'on',
#   'how',
#   'to',
#   'include',
#   'others',
#   '.'),
#  '10002000_1_2': ('let',
#   'the',
#   'student',
#   'direct',
#   'a',
#   'discussion',
#   'or',
#   'activity',
#   '.'),
#  '10002000_1_3': ('designate',
#   'an',
#   'object',
#   'that',
#   'a',
#   'student',
#   'must',
#   'be',
#   'holding',
#   'in',
#   'order',
#   'to',
#   'speak',
#   '.'),
#  '10002000_2_0': ('set', 'clear', 'classroom', 'expectations', '.'),
#  '10002000_2_1': ('meet',
#   'your',
#   'students',
#   'at',
#   'the',
#   'door',
#   'every',
#   'day',
#   'before',
#   'class',
#   '.'),
#  '10002000_2_2': ('set',
#   'aside',
#   'time',
#   'to',
#   'allow',
#   'students',
#   'to',
#   'talk',
#   '.'),
#  '10002000_2_3': ('use',
#   'call',
#   'and',
#   'response',
#   'to',
#   'get',
#   'students',
#   '’',
#   'attention',
#   '.'),
#  '10002000_2_4': ('use',
#   'a',
#   'sound',
#   'signal',
#   ',',
#   'such',
#   'as',
#   'a',
#   'bell',
#   'or',
#   'rainstick',
#   '.'),
#  '10002000_2_5': ('reward', 'students', 'for', 'meeting', 'expectations', '.'),
#  '100021_0_0': ('choose', 'your', 'fabric', '.'),
#  '100021_0_1': ('wash', 'the', 'fabric', '.'),
#  '100021_0_2': ('select', 'a', 'pattern', '.'),
#  '100021_0_3': ('make', 'a', 'faux', '-', 'pattern', '.'),
#  '100021_0_4': ('take', 'your', 'measurements', '.'),
#  '100021_1_0': ('cut', 'your', 'fabric', '.'),
#  '100021_1_1': ('begin', 'sewing', '.'),
#  '100021_1_2': ('sew', 'the', 'neckline', '.'),
#  '100021_1_3': ('add', 'the', 'hem', '.'),
#  '100021_1_4': ('finish', 'off', 'your', 'dress', '.'),
#  '100021_2_0': ('use',
#   'a',
#   'fitted',
#   'bedsheet',
#   'to',
#   'make',
#   'a',
#   'dress',
#   '.'),
#  '100021_2_1': ('expand',
#   'your',
#   'favorite',
#   'skirt',
#   'into',
#   'a',
#   'dress',
#   '.'),
#  '100021_2_2': ('make', 'a', '1920s', 'flapper', 'dress', '.'),
#  '100021_2_3': ('make', 'your', 'own', 'prom', 'dress', '.'),
#  '1000266_0_0': ('check', 'the', 'label', '.'),
#  '1000266_0_1': ('avoid', 'lead', '-', 'laced', 'toys', '.'),
#  '1000266_0_2': ('beware', 'of', 'tennis', 'balls', '.'),
#  '1000266_0_3': ('purchase', 'hard', 'rubber', 'toys', '.'),
#  '1000266_0_4': ('stay',
#   'away',
#   'from',
#   'toys',
#   'intended',
#   'for',
#   'children',
#   '.'),
#  '1000266_0_5': ('inspect', 'stuffed', 'toys', 'manually', '.'),
#  '1000266_0_6': ('check', 'with', 'your', 'vet', 'about', 'rawhide', '.'),
#  '1000266_0_7': ('keep',
#   'your',
#   'dog',
#   'away',
#   'from',
#   'hazardous',
#   'items',
#   'in',
#   'the',
#   'home',
#   '.'),
#  '1000266_1_0': ('know', 'your', 'dog', '’s', 'habits', '.'),
#  '1000266_1_1': ('supervise',
#   'your',
#   'dog',
#   'when',
#   'chewing',
#   'rawhide',
#   'or',
#   'tennis',
#   'balls',
#   '.'),
#  '1000266_1_2': ('get', 'rid', 'of', 'damaged', 'toys', '.'),
#  '1000266_1_3': ('rotate', 'different', 'toys', '.'),
#  '1000266_1_4': ('clean', 'toys', 'regularly', '.'),
#  '10004257_0_0': ('write',
#   'a',
#   'catchy',
#   'headline',
#   'to',
#   'grab',
#   'reader',
#   '’s',
#   'attention',
#   '.'),
#  '10004257_0_1': ('include',
#   'the',
#   'general',
#   'information',
#   'about',
#   'the',
#   'sale',
#   'in',
#   'the',
#   'body',
#   'of',
#   'the',
#   'ad',
#   '.'),
#  '10004257_0_2': ('list',
#   'examples',
#   'of',
#   'some',
#   'of',
#   'your',
#   'items',
#   'so',
#   'shoppers',
#   'know',
#   'what',
#   'to',
#   'expect',
#   '.'),
#  '10004257_0_3': ('include',
#   'pictures',
#   'of',
#   'some',
#   'of',
#   'your',
#   'best',
#   'items',
#   'if',
#   'the',
#   'site',
#   'allows',
#   'you',
#   'to',
#   '.'),
#  '10004257_0_4': ('put',
#   'your',
#   'contact',
#   'information',
#   'if',
#   'you',
#   'want',
#   'people',
#   'to',
#   'be',
#   'able',
#   'to',
#   'reach',
#   'you',
#   '.'),
#  '10004257_0_5': ('post',
#   'your',
#   'ad',
#   'on',
#   'an',
#   'online',
#   'classified',
#   'advertisement',
#   'website',
#   '.'),
#  '10004257_1_0': ('use',
#   'facebook',
#   'marketplace',
#   'to',
#   'promote',
#   'your',
#   'sale',
#   '.'),
#  '10004257_1_1': ('place',
#   'an',
#   'ad',
#   'on',
#   'your',
#   'local',
#   'newspaper',
#   '’s',
#   'website',
#   'to',
#   'reach',
#   'more',
#   'people',
#   '.'),
#  '10004257_1_2': ('post',
#   'about',
#   'your',
#   'sale',
#   'on',
#   'your',
#   'personal',
#   'social',
#   'media',
#   'accounts',
#   '.'),
#  '10004257_1_3': ('send',
#   'an',
#   'email',
#   'to',
#   'all',
#   'of',
#   'your',
#   'contacts',
#   'to',
#   'personally',
#   'invite',
#   'them',
#   '.'),
#  '10004257_2_0': ('use',
#   'word',
#   'of',
#   'mouth',
#   'to',
#   'inform',
#   'the',
#   'people',
#   'you',
#   'know',
#   '.'),
#  '10004257_2_1': ('create',
#   'flyers',
#   'to',
#   'target',
#   'shoppers',
#   'and',
#   'drivers',
#   '.'),
#  '10004257_2_2': ('put',
#   'an',
#   'ad',
#   'in',
#   'a',
#   'newspaper',
#   'or',
#   'newsletter',
#   'to',
#   'inform',
#   'those',
#   'who',
#   'are',
#   'n’t',
#   'online',
#   '.'),
#  '1000430_0_0': ('write',
#   'down',
#   'your',
#   'goals',
#   'for',
#   'your',
#   'business',
#   '.'),
#  '1000430_0_1': ('select',
#   'a',
#   'clothing',
#   'style',
#   'or',
#   'type',
#   'that',
#   'you',
#   'want',
#   'to',
#   'sell',
#   '.'),
#  '1000430_0_2': ('create', 'a', 'name', 'for', 'your', 'business', '.'),
#  '1000430_0_3': ('come',
#   'up',
#   'with',
#   'a',
#   'marketing',
#   'strategy',
#   'for',
#   'your',
#   'business',
#   '.'),
#  '1000430_1_0': ('put',
#   'together',
#   'a',
#   'business',
#   'plan',
#   'to',
#   'attract',
#   'investors',
#   '.'),
#  '1000430_1_1': ('pitch',
#   'your',
#   'business',
#   'idea',
#   'to',
#   'secure',
#   'startup',
#   'costs',
#   '.'),
#  '1000430_1_2': ('select',
#   'an',
#   'llc',
#   ',',
#   'partnership',
#   ',',
#   'or',
#   'sole',
#   'proprietor',
#   'legal',
#   'structure',
#   '.'),
#  '1000430_1_3': ('get',
#   'the',
#   'necessary',
#   'licenses',
#   'and',
#   'permits',
#   'to',
#   'operate',
#   'your',
#   'business',
#   '.'),
#  '1000430_1_4': ('draft',
#   'company',
#   'policies',
#   'for',
#   'employees',
#   'and',
#   'customers',
#   '.'),
#  '1000430_1_5': ('post', 'an', 'ad', 'to', 'hire', 'employees', '.'),
#  '1000430_1_6': ('set',
#   'up',
#   'a',
#   'cloud',
#   '-',
#   'based',
#   'point',
#   'of',
#   'sale',
#   'system',
#   'with',
#   'a',
#   'tablet',
#   '.'),
#  '1000430_2_0': ('look',
#   'for',
#   'areas',
#   'with',
#   'lots',
#   'of',
#   'foot',
#   'traffic',
#   '.'),
#  '1000430_2_1': ('check',
#   'to',
#   'see',
#   'if',
#   'you',
#   'can',
#   'see',
#   'the',
#   'storefront',
#   'from',
#   'the',
#   'road',
#   '.'),
#  '1000430_2_2': ('select',
#   'a',
#   'storefront',
#   'in',
#   'an',
#   'area',
#   'that',
#   'your',
#   'target',
#   'demographic',
#   'frequents',
#   '.'),
#  '1000430_2_3': ('research',
#   'the',
#   'safety',
#   'and',
#   'security',
#   'of',
#   'the',
#   'locations',
#   'you',
#   'scout',
#   '.'),
#  '1000430_2_4': ('look',
#   'for',
#   'locations',
#   'with',
#   'rents',
#   'that',
#   'you',
#   'can',
#   'afford',
#   '.'),
#  '1000430_3_0': ('contact',
#   'wholesale',
#   'vendors',
#   'who',
#   'carry',
#   'clothing',
#   'that',
#   'you',
#   'want',
#   'to',
#   'sell',
#   '.'),
#  '1000430_3_1': ('go',
#   'to',
#   'trade',
#   'shows',
#   'to',
#   'buy',
#   'wholesale',
#   'merchandise',
#   'for',
#   'your',
#   'store',
#   '.'),
#  '1000430_3_2': ('price',
#   'your',
#   'inventory',
#   'to',
#   'be',
#   'affordable',
#   'but',
#   'also',
#   'turn',
#   'a',
#   'profit',
#   '.'),
#  '1000430_3_3': ('create',
#   'a',
#   'checkout',
#   'station',
#   'for',
#   'your',
#   'cashiers',
#   '.'),
#  '1000430_3_4': ('set',
#   'up',
#   'mannequins',
#   ',',
#   'display',
#   'racks',
#   ',',
#   'and',
#   'seating',
#   'for',
#   'customers',
#   '.'),
#  '1000430_3_5': ('arrange',
#   'your',
#   'inventory',
#   'in',
#   'your',
#   'store',
#   'so',
#   'it',
#   'catches',
#   'people',
#   "'s",
#   'attention',
#   '.'),
#  '1000430_4_0': ('create', 'a', 'website', 'for', 'your', 'store', '.'),
#  '1000430_4_1': ('set',
#   'up',
#   'social',
#   'media',
#   'accounts',
#   'for',
#   'your',
#   'business',
#   '.'),
#  '1000430_4_2': ('use',
#   'digital',
#   'marketing',
#   'to',
#   'promote',
#   'your',
#   'business',
#   '.'),
#  '10004451_0_0': ('browse',
#   'through',
#   'patterns',
#   'for',
#   'guidance',
#   'and',
#   'inspiration',
#   '.'),
#  '10004451_0_1': ('choose', 'your', 'yarn', '.'),
#  '10004451_0_2': ('select',
#   'an',
#   'appropriately',
#   'sized',
#   'crochet',
#   'hook',
#   '.'),
#  '10004451_0_3': ('decide', 'on', 'a', 'stitch', 'type', '.'),
#  '10004451_1_0': ('make', 'a', 'slipknot', '.'),
#  '10004451_1_1': ('crochet',
#   'a',
#   'chain',
#   'long',
#   'enough',
#   'to',
#   'wrap',
#   'tightly',
#   'around',
#   'the',
#   'width',
#   'of',
#   'the',
#   'pillow',
#   '.'),
#  '10004451_1_2': ('attach',
#   'the',
#   'ends',
#   'of',
#   'the',
#   'chain',
#   'with',
#   'a',
#   'slipstitch',
#   '.'),
#  '10004451_1_3': ('work', 'the', 'chain', 'in', 'single', 'crochet', '.'),
#  '10004451_2_0': ('crochet',
#   'the',
#   'rounds',
#   'in',
#   'your',
#   'desired',
#   'stitch',
#   '.'),
#  '10004451_2_1': ('secure', 'the', 'last', 'stitch', '.'),
#  '10004451_2_2': ('thread',
#   'a',
#   'yarn',
#   'needle',
#   'and',
#   'sew',
#   'up',
#   '1',
#   'end',
#   'of',
#   'the',
#   'pillow',
#   'cover',
#   '.'),
#  '10004451_2_3': ('insert', 'the', 'pillow', 'into', 'the', 'cover', '.'),
#  '10004451_2_4': ('sew',
#   'the',
#   'other',
#   'end',
#   'of',
#   'the',
#   'pillow',
#   'cover',
#   'closed',
#   '.'),
#  '10004709_0_0': ('ask',
#   'them',
#   'to',
#   'come',
#   'into',
#   'the',
#   'office',
#   'for',
#   'training',
#   'if',
#   'possible',
#   '.'),
#  '10004709_0_1': ('set',
#   'up',
#   'conference',
#   'calls',
#   'for',
#   'personalized',
#   'training',
#   '.'),
#  '10004709_0_2': ('use',
#   'an',
#   'instant',
#   'messaging',
#   'service',
#   'to',
#   'answer',
#   'questions',
#   'quickly',
#   '.'),
#  '10004709_0_3': ('send',
#   'emails',
#   'if',
#   'the',
#   'employee',
#   'works',
#   'on',
#   'their',
#   'own',
#   'schedule',
#   '.'),
#  '10004709_2_0': ('give', 'the', 'employee', 'benchmarks', 'to', 'reach', '.'),
#  '10004709_2_1': ('provide',
#   'specific',
#   'feedback',
#   'on',
#   'the',
#   'first',
#   'several',
#   'tasks',
#   '.'),
#  '10004709_2_2': ('ask',
#   'for',
#   'feedback',
#   'and',
#   'questions',
#   'from',
#   'the',
#   'employee',
#   '.'),
#  '10004709_2_3': ('communicate',
#   'regularly',
#   'with',
#   'all',
#   'remote',
#   'employees',
#   '.'),
#  '10004867_0_0': ('hire', 'an', 'attorney', '.'),
#  '10004867_0_1': ('find', 'the', 'original', 'will', '.'),
#  '10004867_0_2': ('draft', 'a', 'petition', 'to', 'admit', 'the', 'will', '.'),
#  '10004867_0_3': ('get',
#   'a',
#   'certified',
#   'copy',
#   'of',
#   'the',
#   'death',
#   'certificate',
#   '.'),
#  '10004867_0_4': ('apply', 'for', 'probate', '.'),
#  '10004867_0_5': ('notify', 'the', 'family', 'of', 'the', 'deceased', '.'),
#  '10004867_0_6': ('submit',
#   'your',
#   'documents',
#   'and',
#   'fees',
#   'to',
#   'the',
#   'court',
#   'clerk',
#   '.'),
#  '10004867_1_0': ('see', 'who', 'is', 'named', 'in', 'the', 'will', '.'),
#  '10004867_1_1': ('name',
#   'an',
#   'agent',
#   'if',
#   'you',
#   'live',
#   'out',
#   'of',
#   'state',
#   '.'),
#  '10004867_1_2': ('complete',
#   'a',
#   'fiduciary',
#   'training',
#   'course',
#   'if',
#   'required',
#   '.'),
#  '10004867_1_3': ('take', 'your', 'oath', 'or', 'affirmation', '.'),
#  '10004867_1_4': ('post', 'bond', 'if', 'required', '.'),
#  '10004867_2_0': ('take',
#   'a',
#   'preliminary',
#   'inventory',
#   'of',
#   'the',
#   'estate',
#   '.'),
#  '10004867_2_1': ('complete', 'the', 'application', 'form', '.'),
#  '10004867_2_2': ('submit',
#   'a',
#   'draft',
#   'order',
#   'for',
#   'letters',
#   'with',
#   'your',
#   'application',
#   '.'),
#  '10004867_2_3': ('pick',
#   'up',
#   'your',
#   'letters',
#   'from',
#   'the',
#   'clerk',
#   '.'),
#  '10004867_2_4': ('make', 'copies', 'of', 'your', 'letters', '.'),
#  '100049_0_0': ('make',
#   'an',
#   'easy',
#   ',',
#   'quick',
#   '3d',
#   'paper',
#   'snowflake',
#   '.'),
#  '100049_0_1': ('or', ',', 'make', 'a', 'classic', 'paper', 'snowflake', '.'),
#  '100049_0_2': ('make', 'your', 'own', 'christmas', 'wreath', '.'),
#  '100049_0_3': ('for',
#   'a',
#   'more',
#   'modern',
#   '(',
#   'and',
#   'environmentally',
#   '-',
#   'friendly',
#   '!',
#   ')'),
#  '100049_0_4': ('make',
#   'a',
#   'cute',
#   'snowman',
#   'out',
#   'of',
#   'a',
#   'gourd',
#   '.'),
#  '100049_0_5': ('make', 'an', 'advent', 'paper', 'chain', '.'),
#  '100049_1_0': ('give',
#   'your',
#   'tree',
#   'an',
#   'elegant',
#   ',',
#   'classic',
#   'feel',
#   '.'),
#  '100049_1_1': ('make', 'tiny', '3d', 'christmas', 'trees', '.'),
#  '100049_1_2': ('make', 'a', 'popcorn', 'garland', 'for', 'your', 'tree', '.'),
#  '100049_1_3': ('make', 'sparkly', 'snowflake', 'ornaments', '.'),
#  '100049_1_4': ('make', 'a', 'mini', '-', 'tree', 'out', 'of', 'books', '.'),
#  '100049_2_0': ('deck',
#   'out',
#   'your',
#   'front',
#   'yard',
#   'for',
#   'the',
#   'holiday',
#   '.'),
#  '100049_2_1': ('make',
#   'your',
#   'outdoor',
#   'christmas',
#   'lights',
#   'flash',
#   'to',
#   'music',
#   '.'),
#  '10005020_0_0': ('purchase', 'a', 'floor', 'gap', 'fixer', 'tool', '.'),
#  '10005020_0_1': ('remove',
#   'the',
#   'protective',
#   'backing',
#   'from',
#   'the',
#   'adhesive',
#   'face',
#   'of',
#   'the',
#   'block',
#   '.'),
#  '10005020_0_2': ('position',
#   'the',
#   'block',
#   '1',
#   'inch',
#   '(',
#   '2.5',
#   'cm',
#   ')',
#   'from',
#   'the',
#   'end',
#   'of',
#   'one',
#   'of',
#   'the',
#   'displaced',
#   'planks',
#   '.'),
#  '10005020_0_3': ('work',
#   'your',
#   'way',
#   'toward',
#   'the',
#   'center',
#   'of',
#   'the',
#   'floor',
#   'and',
#   'away',
#   'from',
#   'the',
#   'wall',
#   '.'),
#  '10005020_0_4': ('tap',
#   'the',
#   'end',
#   'of',
#   'the',
#   'block',
#   'with',
#   'a',
#   'mallet',
#   'to',
#   'close',
#   'the',
#   'gap',
#   '.'),
#  '10005020_0_5': ('repeat', 'with', 'any', 'remaining', 'gaps', '.'),
#  '10005020_1_0': ('scoop',
#   'up',
#   'a',
#   'glob',
#   'of',
#   'wood',
#   'glue',
#   'using',
#   'a',
#   'small',
#   'utensil',
#   '.'),
#  '10005020_1_1': ('swab',
#   'the',
#   'glue',
#   'onto',
#   'the',
#   'exposed',
#   'tongue',
#   'of',
#   'the',
#   'displaced',
#   'plank',
#   '.'),
#  '10005020_1_2': ('push',
#   'the',
#   'separated',
#   'planks',
#   'together',
#   'to',
#   'close',
#   'the',
#   'gap',
#   '.'),
#  '10005020_1_3': ('wipe', 'away', 'the', 'excess', 'glue', '.'),
#  '10005020_2_0': ('allow',
#   'your',
#   'laminate',
#   'flooring',
#   'to',
#   'acclimate',
#   'for',
#   '48',
#   '-',
#   '72',
#   'hours',
#   '.'),
#  '10005020_2_1': ('make',
#   'sure',
#   'the',
#   'subflooring',
#   'is',
#   'perfectly',
#   'level',
#   '.'),
#  '10005020_2_2': ('have',
#   'your',
#   'laminate',
#   'flooring',
#   'installed',
#   'professionally',
#   '.'),
#  '10005292_0_0': ('allow',
#   'yourself',
#   'to',
#   'feel',
#   'without',
#   'judgment',
#   '.'),
#  '10005292_0_1': ('vent',
#   'your',
#   'feelings',
#   'in',
#   'a',
#   'healthy',
#   'way',
#   '.'),
#  '10005292_0_2': ('talk',
#   'with',
#   'other',
#   'people',
#   'who',
#   'ca',
#   'n’t',
#   'or',
#   'do',
#   'n’t',
#   'celebrate',
#   'with',
#   'their',
#   'mothers',
#   '.'),
#  '10005292_1_0': ('surround',
#   'yourself',
#   'with',
#   'people',
#   'you',
#   'love',
#   ',',
#   'if',
#   'it',
#   'feels',
#   'right',
#   '.'),
#  '10005292_1_1': ('bake', 'one', 'of', 'her', 'favorite', 'recipes', '.'),
#  '10005292_1_2': ('spend',
#   'time',
#   'in',
#   'one',
#   'of',
#   'her',
#   'favorite',
#   'places',
#   '.'),
#  '10005292_1_3': ('write',
#   'down',
#   'her',
#   'unique',
#   'sayings',
#   'or',
#   'your',
#   'favorite',
#   'memories',
#   'of',
#   'her',
#   '.'),
#  '10005292_1_4': ('look',
#   'back',
#   'through',
#   'pictures',
#   'you',
#   'have',
#   'through',
#   'her',
#   '.'),
#  '10005292_1_5': ('visit',
#   'her',
#   'grave',
#   'site',
#   'or',
#   'mausoleum',
#   ',',
#   'if',
#   'she',
#   'has',
#   'one',
#   '.'),
#  '10005292_2_0': ('stay', 'in', 'and', 'relax', '.'),
#  '10005292_2_1': ('exercise',
#   'to',
#   'distract',
#   'yourself',
#   'and',
#   'get',
#   'out',
#   'of',
#   'the',
#   'house',
#   '.'),
#  '10005292_2_2': ('get',
#   'away',
#   'for',
#   'the',
#   'weekend',
#   'if',
#   'you',
#   'have',
#   'time',
#   'to',
#   'plan',
#   '.'),
#  '10005292_2_3': ('avoid',
#   'things',
#   'that',
#   'could',
#   'remind',
#   'you',
#   'of',
#   'your',
#   'mom',
#   'or',
#   'the',
#   'holiday',
#   '.'),
#  '10006187_0_0': ('find',
#   'a',
#   'cardboard',
#   'box',
#   'big',
#   'enough',
#   'to',
#   'accommodate',
#   'your',
#   'light',
#   'fixture',
#   '.'),
#  '10006187_0_1': ('place',
#   'a',
#   'piece',
#   'of',
#   'foam',
#   'underneath',
#   'your',
#   'light',
#   'fixture',
#   '.'),
#  '10006187_0_2': ('raise',
#   'your',
#   'light',
#   'fixture',
#   'with',
#   'a',
#   'stick',
#   'if',
#   'it',
#   "'s",
#   'not',
#   'a',
#   'flat',
#   'bottom',
#   '.'),
#  '10006187_0_3': ('wash',
#   'the',
#   'fixture',
#   'in',
#   'hot',
#   'water',
#   'if',
#   'it',
#   "'s",
#   'covered',
#   'in',
#   'a',
#   'lacquer',
#   '.'),
#  '10006187_0_4': ('clean',
#   'and',
#   'dry',
#   'your',
#   'brass',
#   'light',
#   'fixture',
#   'with',
#   'a',
#   'cloth',
#   'and',
#   'lukewarm',
#   'water',
#   '.'),
#  '10006187_0_5': ('clean',
#   'copper',
#   'fixtures',
#   'using',
#   'a',
#   'cloth',
#   'with',
#   'salt',
#   'and',
#   'white',
#   'vinegar',
#   '.'),
#  '10006187_0_6': ('polish',
#   'stainless',
#   'steel',
#   'fixtures',
#   'using',
#   'a',
#   'cloth',
#   'and',
#   'vinegar',
#   '.'),
#  '10006187_0_7': ('choose',
#   'the',
#   'type',
#   'of',
#   'paint',
#   'your',
#   'want',
#   'for',
#   'your',
#   'light',
#   'fixture',
#   '.'),
#  '10006187_0_8': ('spray',
#   'a',
#   'coat',
#   'of',
#   'metal',
#   'primer',
#   'onto',
#   'your',
#   'light',
#   'fixture',
#   '.'),
#  '10006187_0_9': ('apply',
#   'light',
#   'and',
#   'even',
#   'coats',
#   'of',
#   'spray',
#   'paint',
#   'onto',
#   'your',
#   'light',
#   'fixture',
#   '.'),
#  '10006187_0_10': ('use',
#   'a',
#   'tack',
#   'cloth',
#   'to',
#   'pick',
#   'up',
#   'any',
#   'dust',
#   'and',
#   'dirt',
#   'as',
#   'you',
#   'paint',
#   '.'),
#  '10006187_1_0': ('cover',
#   'utilitarian',
#   'light',
#   'fixtures',
#   'with',
#   'a',
#   'ceiling',
#   'light',
#   'cover',
#   '.'),
#  '10006187_1_1': ('create',
#   'a',
#   'shade',
#   'out',
#   'of',
#   'a',
#   'plastic',
#   'basket',
#   'or',
#   'bin',
#   '.'),
#  '10006187_1_2': ('find',
#   'or',
#   'purchase',
#   'a',
#   'chopping',
#   'board',
#   'to',
#   'act',
#   'as',
#   'a',
#   'cover',
#   '.'),
#  '10006187_1_3': ('cover',
#   'your',
#   'fixture',
#   'with',
#   'a',
#   'plain',
#   'drum',
#   'lamp',
#   'shade',
#   '.'),
#  '10006187_2_0': ('flip',
#   'the',
#   'arms',
#   'of',
#   'a',
#   'standard',
#   'light',
#   'fixture',
#   'for',
#   'a',
#   'chandelier',
#   'design',
#   '.'),
#  '10006187_2_1': ('wrap',
#   'your',
#   'chandelier',
#   'with',
#   'rope',
#   'or',
#   'twine',
#   'for',
#   'a',
#   'nautical',
#   'vibe',
#   '.'),
#  '10006187_2_2': ('string',
#   'beads',
#   'around',
#   'your',
#   'fixture',
#   'if',
#   "it's",
#   'a',
#   'chandelier',
#   '.'),
#  '1000640_0_0': ('go',
#   'to',
#   'http://developers.facebook.com/docs/reference/plugins/like',
#   '.'),
#  '1000640_0_1': ('choose', 'your', 'options', '.'),
#  '1000640_0_2': ('after',
#   'entering',
#   'the',
#   'url',
#   'of',
#   'your',
#   'blog',
#   ',',
#   'right',
#   '-',
#   'click',
#   'the',
#   'button',
#   'and',
#   'select',
#   '"',
#   'open',
#   'frame',
#   'in',
#   'new',
#   'tab',
#   '/',
#   'window',
#   '"',
#   '.'),
#  '1000640_0_3': ('copy', 'the', 'url', 'that', 'opens', '.'),
#  '1000640_1_0': ('go', 'to', 'your', 'blog', "'s", 'dashboard', '.'),
#  '1000640_1_1': ('go', 'to', 'appearance', '>', 'widgets', '.'),
#  '1000640_1_2': ('drag', 'a', 'text', 'widget', 'to', 'your', 'sidebar', '.'),
#  '1000640_1_3': ('copy',
#   'and',
#   'paste',
#   'the',
#   'following',
#   'into',
#   'the',
#   'widget',
#   ':'),
#  '1000644_0_0': ('draw', 'a', 'cross', 'outline', '.'),
#  '1000644_0_1': ('draw', 'more', 'squares', 'of', 'the', 'same', 'size', '.'),
#  '1000644_0_2': ('draw',
#   '2',
#   'more',
#   'squares',
#   'below',
#   'the',
#   'bottom',
#   'square',
#   '.'),
#  '1000644_0_3': ('divide',
#   'the',
#   'squares',
#   'on',
#   'the',
#   'left',
#   'and',
#   'on',
#   'the',
#   'right',
#   'of',
#   'the',
#   'cross',
#   ',',
#   'vertically',
#   'and',
#   'the',
#   'remaining',
#   'squares',
#   'horizontally',
#   '.'),
#  '1000644_0_4': ('draw', 'the', 'center', 'with', 'a', 'marker', '.'),
#  '1000644_0_5': ('erase', 'your', 'guidelines', 'completely', '.'),
#  '1000644_1_0': ('draw', 'a', 'cross', 'outline', '.'),
#  '1000644_1_1': ('draw', 'more', 'squares', 'of', 'the', 'same', 'size', '.'),
#  '1000644_1_2': ('draw',
#   '2',
#   'more',
#   'squares',
#   'below',
#   'the',
#   'bottom',
#   'square',
#   '.'),
#  '1000644_1_3': ('with',
#   'a',
#   'compass',
#   'draw',
#   '3',
#   'circles',
#   'each',
#   'for',
#   'the',
#   'arms',
#   'of',
#   'the',
#   'cross',
#   '.'),
#  '1000644_1_4': ('fill',
#   'in',
#   'the',
#   'shapes',
#   'with',
#   'the',
#   'color',
#   'you',
#   'want',
#   '.'),
#  '1000644_1_5': ('erase', 'all', 'guidelines', 'completely', '.'),
#  '1000676_0_0': ('find',
#   'a',
#   'rabbit',
#   'show',
#   'held',
#   'by',
#   'arba',
#   ',',
#   '4',
#   '-',
#   'h',
#   ',',
#   'or',
#   'ffa',
#   '.'),
#  '1000676_0_1': ('request',
#   'a',
#   'show',
#   'catalog',
#   'from',
#   'the',
#   'show',
#   'secretary',
#   '.'),
#  '1000676_0_2': ('enter',
#   'your',
#   'rabbit',
#   'in',
#   'the',
#   'appropriate',
#   'class',
#   'for',
#   'age',
#   ',',
#   'weight',
#   ',',
#   'or',
#   'breed',
#   '.'),
#  '1000676_0_3': ('review', 'the', 'show', "'s", 'judging', 'procedures', '.'),
#  '1000676_1_0': ('check',
#   'your',
#   'rabbit',
#   'for',
#   'diseases',
#   'to',
#   'make',
#   'sure',
#   'it',
#   '’s',
#   'healthy',
#   '.'),
#  '1000676_1_1': ('start',
#   'a',
#   'supplemental',
#   'conditioner',
#   '90',
#   'days',
#   'before',
#   'the',
#   'show',
#   '.'),
#  '1000676_1_2': ('give',
#   'your',
#   'rabbit',
#   'plenty',
#   'of',
#   'fresh',
#   ',',
#   'clean',
#   'water',
#   '.'),
#  '1000676_1_3': ('continue',
#   'feeding',
#   'your',
#   'rabbit',
#   'hay',
#   ',',
#   'pellets',
#   'and',
#   'vegetables',
#   'regularly',
#   '.'),
#  '1000676_1_4': ('get',
#   'your',
#   'rabbit',
#   'accustomed',
#   'to',
#   'being',
#   'handled',
#   'by',
#   'other',
#   'people',
#   '.'),
#  '1000676_1_5': ('practice',
#   'posing',
#   'your',
#   'rabbit',
#   'to',
#   'prepare',
#   'for',
#   'judging',
#   '.'),
#  '1000676_2_0': ('trim',
#   'your',
#   'rabbit',
#   '’s',
#   'toenails',
#   'at',
#   'home',
#   'with',
#   'pet',
#   'nail',
#   'clippers',
#   '.'),
#  '1000676_2_1': ('clean',
#   'any',
#   'discharge',
#   'or',
#   'buildup',
#   'with',
#   'a',
#   'moistened',
#   'cloth',
#   'or',
#   'towel',
#   '.'),
#  '1000676_2_2': ('brush',
#   'your',
#   'rabbit',
#   'before',
#   'the',
#   'show',
#   'to',
#   'keep',
#   'its',
#   'fur',
#   'neat',
#   '.'),
#  '1000676_3_0': ('keep',
#   'your',
#   'rabbit',
#   'cool',
#   'and',
#   'comfortable',
#   'while',
#   'transporting',
#   'it',
#   '.'),
#  '1000676_3_1': ('bring',
#   'a',
#   'grooming',
#   'kit',
#   ',',
#   'show',
#   'coop',
#   ',',
#   'and',
#   'your',
#   'belongings',
#   'to',
#   'the',
#   'show',
#   '.'),
#  '1000676_3_2': ('be',
#   'present',
#   'when',
#   'your',
#   'rabbit',
#   'is',
#   'judged',
#   'so',
#   'you',
#   'can',
#   'hear',
#   'feedback',
#   '.'),
#  '1000676_3_3': ('remove',
#   'your',
#   'rabbit',
#   'promptly',
#   'when',
#   'the',
#   'judge',
#   'is',
#   'finished',
#   '.'),
#  '1000676_3_4': ('put',
#   'your',
#   'rabbit',
#   'back',
#   'in',
#   'its',
#   'carrier',
#   'after',
#   'it',
#   'has',
#   'been',
#   'judged',
#   '.'),
#  '100069_0_0': ('assemble', 'your', 'materials', '.'),
#  '100069_0_1': ('pierce', 'a', 'hole', 'in', 'the', 'pick', '.'),
#  '100069_0_2': ('drill', 'a', 'hole', 'in', 'the', 'pick', '.'),
#  '100069_0_3': ('insert', 'the', 'jump', 'ring', '.'),
#  '10007812_0_0': ('ignore',
#   'them',
#   'if',
#   'they',
#   'do',
#   'something',
#   'that',
#   'bothers',
#   'you',
#   '.'),
#  '10007812_0_1': ('remain', 'calm', 'during', 'their', 'antics', '.'),
#  '10007812_0_2': ('ask',
#   'for',
#   'just',
#   'the',
#   'facts',
#   'if',
#   'they',
#   'try',
#   'to',
#   'play',
#   'the',
#   'victim',
#   '.'),
#  '10007812_0_3': ('learn',
#   'to',
#   'walk',
#   'away',
#   'during',
#   'dangerous',
#   'or',
#   'extreme',
#   'situations',
#   '.'),
#  '10007812_1_0': ('tell',
#   'them',
#   'what',
#   'behavior',
#   'you',
#   'will',
#   'and',
#   'wo',
#   'n’t',
#   'tolerate',
#   '.'),
#  '10007812_1_1': ('set',
#   'time',
#   'limits',
#   'for',
#   'conversations',
#   'and',
#   'talks',
#   '.'),
#  '10007812_1_2': ('stop',
#   'following',
#   'their',
#   'social',
#   'media',
#   'accounts',
#   '.'),
#  '10007812_1_3': ('minimize',
#   'contact',
#   'if',
#   'they',
#   'are',
#   'causing',
#   'stress',
#   ',',
#   'anxiety',
#   ',',
#   'or',
#   'annoyance',
#   '.'),
#  '10007812_2_0': ('determine',
#   'if',
#   'there',
#   'is',
#   'an',
#   'underlying',
#   'cause',
#   'to',
#   'their',
#   'behavior',
#   '.'),
#  '10007812_2_1': ('boost',
#   'their',
#   'self',
#   '-',
#   'esteem',
#   'when',
#   'they',
#   'are',
#   'not',
#   'actively',
#   'seeking',
#   'your',
#   'attention',
#   '.'),
#  '10007812_2_2': ('suggest',
#   'that',
#   'they',
#   'get',
#   'professional',
#   'help',
#   'if',
#   'you',
#   'think',
#   'they',
#   'will',
#   'hurt',
#   'themselves',
#   '.'),
#  '10007877_0_0': ('purchase', 'a', 'salt', 'mix', 'made', 'for', 'reefs', '.'),
#  '10007877_0_1': ('fill',
#   'a',
#   'bucket',
#   'with',
#   '4',
#   'us',
#   'gal',
#   '(',
#   '15',
#   'l',
#   ')',
#   'of',
#   'distilled',
#   'water',
#   '.'),
#  '10007877_0_2': ('pour',
#   'in',
#   'the',
#   'amount',
#   'of',
#   'salt',
#   'mix',
#   'as',
#   'specified',
#   'in',
#   'the',
#   'instructions',
#   'and',
#   'stir',
#   '.'),
#  '10007877_0_3': ('test',
#   'the',
#   'water',
#   'with',
#   'a',
#   'hydrometer',
#   'until',
#   'the',
#   'specific',
#   'gravity',
#   'is',
#   '1.025',
#   '.'),
#  '10007877_0_4': ('submerge',
#   'a',
#   'pump',
#   'and',
#   'heater',
#   'to',
#   'circulate',
#   'and',
#   'heat',
#   'the',
#   'water',
#   '.'),
#  '10007877_0_5': ('let',
#   'the',
#   'water',
#   'circulate',
#   'and',
#   'heat',
#   'overnight',
#   '.'),
#  '10007877_0_6': ('test',
#   'the',
#   'specific',
#   'gravity',
#   'again',
#   'the',
#   'next',
#   'day',
#   '.'),
#  '10007877_1_0': ('remove',
#   '10',
#   '%',
#   'of',
#   'the',
#   'water',
#   'from',
#   'your',
#   'tank',
#   '.'),
#  '10007877_1_1': ('add',
#   '⁄',
#   '2',
#   'us',
#   'gal',
#   '(',
#   '1.9',
#   'l',
#   ')',
#   'of',
#   'the',
#   'solution',
#   'to',
#   'your',
#   'tank',
#   '.'),
#  '10007877_1_2': ('check',
#   'the',
#   'specific',
#   'gravity',
#   'after',
#   '1',
#   'hour',
#   '.'),
#  '10007877_1_3': ('continue',
#   'adding',
#   '⁄',
#   '2',
#   'us',
#   'gal',
#   '(',
#   '1.9',
#   'l',
#   ')',
#   'until',
#   'you',
#   'reach',
#   'the',
#   'desired',
#   'salinity',
#   '.'),
#  '10007877_2_0': ('top',
#   'off',
#   'evaporated',
#   'water',
#   'with',
#   'fresh',
#   'water',
#   'if',
#   'the',
#   'salinity',
#   'is',
#   'too',
#   'high',
#   '.'),
#  '10007877_2_1': ('change',
#   '20',
#   '%',
#   'of',
#   'the',
#   'water',
#   'every',
#   '2',
#   'weeks',
#   '.'),
#  '10007877_2_2': ('match',
#   'the',
#   'salinity',
#   'of',
#   'new',
#   'saltwater',
#   'with',
#   'your',
#   'aquarium',
#   '.'),
#  '10007877_2_3': ('compensate',
#   'for',
#   'salt',
#   'creep',
#   'by',
#   'adding',
#   'saltwater',
#   'solution',
#   'to',
#   'the',
#   'tank',
#   '.'),
#  '10007926_0_0': ('start',
#   'the',
#   'wrap',
#   'at',
#   'the',
#   'mid',
#   'inner',
#   'thigh',
#   'on',
#   'the',
#   'injured',
#   'leg',
#   '.'),
#  '10007926_0_1': ('wrap',
#   'the',
#   'tape',
#   'around',
#   'and',
#   'up',
#   'the',
#   'leg',
#   'as',
#   'high',
#   'as',
#   'possible',
#   '.'),
#  '10007926_0_2': ('bring',
#   'the',
#   'tape',
#   'around',
#   'and',
#   'over',
#   'both',
#   'hips',
#   '.'),
#  '10007926_0_3': ('finish',
#   'the',
#   'wrap',
#   'by',
#   'overlapping',
#   'the',
#   'tape',
#   'on',
#   'the',
#   'upper',
#   'leg',
#   '.'),
#  '10007926_1_0': ('position',
#   'the',
#   'injured',
#   'person',
#   '’s',
#   'leg',
#   'for',
#   'wrapping',
#   '.'),
#  '10007926_1_1': ('start',
#   'the',
#   'wrap',
#   'on',
#   'the',
#   'outer',
#   'mid-thigh',
#   '.'),
#  '10007926_1_2': ('wrap',
#   'up',
#   'to',
#   'the',
#   'top',
#   'of',
#   'the',
#   'leg',
#   'and',
#   'over',
#   'the',
#   'hips',
#   '.'),
#  '10007926_1_3': ('finish',
#   'the',
#   'bandage',
#   'wrap',
#   'around',
#   'the',
#   'leg',
#   '.'),
#  '10007926_1_4': ('tape',
#   'over',
#   'the',
#   'elastic',
#   'bandage',
#   'to',
#   'hold',
#   'it',
#   'in',
#   'place',
#   '.'),
#  '10007926_2_0': ('buy',
#   'a',
#   'groin',
#   'wrap',
#   'or',
#   'specialized',
#   'compression',
#   'shorts',
#   '.'),
#  '10007926_2_1': ('use',
#   'a',
#   'groin',
#   'wrap',
#   'as',
#   'part',
#   'of',
#   'the',
#   'rice',
#   'method',
#   'for',
#   'healing',
#   '.'),
#  '10007926_2_2': ('rest',
#   'your',
#   'injury',
#   'as',
#   'much',
#   'as',
#   'possible',
#   '.'),
#  '10007926_2_3': ('ice',
#   'your',
#   'injured',
#   'groin',
#   'to',
#   'reduce',
#   'pain',
#   '.'),
#  '10007926_2_4': ('elevate', 'your', 'groin', 'while', 'lying', 'down', '.'),
#  '10007926_2_5': ('use',
#   'caution',
#   'when',
#   'engaging',
#   'in',
#   'activities',
#   'that',
#   'may',
#   'reinjure',
#   'the',
#   'muscles',
#   '.'),
#  '10008370_0_0': ('obtain', 'a', 'floating', 'mirror', '.'),
#  '10008370_0_1': ('buy',
#   'spacers',
#   'if',
#   'you',
#   'want',
#   'to',
#   'use',
#   'a',
#   'non-floating',
#   'mirror',
#   'instead',
#   '.'),
#  '10008370_0_2': ('measure',
#   'the',
#   'circumference',
#   'or',
#   'perimeter',
#   'of',
#   'your',
#   'mirror',
#   '.'),
#  '10008370_0_3': ('choose',
#   'warm',
#   'white',
#   '12',
#   'v',
#   'led',
#   'lights',
#   'for',
#   'a',
#   'subtle',
#   'effect',
#   '.'),
#  '10008370_0_4': ('go',
#   'with',
#   'ultra',
#   '-',
#   'bright',
#   'or',
#   'colored',
#   'led',
#   'strips',
#   'for',
#   'a',
#   'modern',
#   'look',
#   '.'),
#  '10008370_0_5': ('obtain',
#   'a',
#   'power',
#   'source',
#   'cable',
#   'that',
#   "'s",
#   'compatible',
#   'with',
#   'your',
#   'led',
#   'strip',
#   '.'),
#  '10008370_1_0': ('flip',
#   'your',
#   'mirror',
#   'over',
#   'and',
#   'place',
#   'the',
#   'end',
#   'of',
#   'your',
#   'led',
#   'strip',
#   'at',
#   'your',
#   'starting',
#   'point',
#   '.'),
#  '10008370_1_1': ('pinch',
#   'the',
#   'led',
#   'strip',
#   'into',
#   'a',
#   'peak',
#   'at',
#   'the',
#   'corners',
#   'if',
#   'your',
#   'mirror',
#   'is',
#   'rectangular',
#   '.'),
#  '10008370_1_2': ('make',
#   'accordion',
#   'folds',
#   'in',
#   'your',
#   'strip',
#   'for',
#   'gentle',
#   'curves',
#   'if',
#   'your',
#   'mirror',
#   'is',
#   'circular',
#   '.'),
#  '10008370_1_3': ('glue',
#   'your',
#   'folds',
#   'into',
#   'place',
#   'with',
#   'super',
#   'glue',
#   '.'),
#  '10008370_1_4': ('remove',
#   'the',
#   'adhesive',
#   'backing',
#   'from',
#   'your',
#   'light',
#   'strip',
#   'and',
#   'attach',
#   'it',
#   'to',
#   'your',
#   'mirror',
#   '.'),
#  '10008370_2_0': ('connect',
#   'your',
#   'lights',
#   'to',
#   'your',
#   'power',
#   'source',
#   'cable',
#   '.'),
#  '10008370_2_1': ('hang',
#   'your',
#   'mirror',
#   'close',
#   'to',
#   'an',
#   'outlet',
#   'to',
#   'manually',
#   'plug',
#   'it',
#   'in',
#   '.'),
#  '10008370_2_2': ('consult',
#   'an',
#   'electrician',
#   'to',
#   'control',
#   'your',
#   'lights',
#   'from',
#   'a',
#   'wall',
#   'switch',
#   '.'),
#  '10008470_0_0': ('find', 'a', 'dmv', 'office', 'near', 'you', '.'),
#  '10008470_0_1': ('fill',
#   'out',
#   'form',
#   'dl',
#   '-',
#   '43',
#   'to',
#   'apply',
#   'for',
#   'a',
#   'replacement',
#   'license',
#   '.'),
#  '10008470_0_2': ('present',
#   'acceptable',
#   'proof',
#   'of',
#   'id',
#   'or',
#   'supporting',
#   'documents',
#   '.'),
#  '10008470_0_3': ('pay',
#   'the',
#   '$',
#   '11',
#   'processing',
#   'fee',
#   'to',
#   'complete',
#   'your',
#   'application',
#   '.'),
#  '10008470_0_4': ('have',
#   'your',
#   'picture',
#   'taken',
#   'and',
#   'submit',
#   'a',
#   'thumbprint',
#   '.'),
#  '10008470_1_0': ('access',
#   'the',
#   'the',
#   'texas',
#   'driver',
#   'license',
#   'renewal',
#   'and',
#   'change',
#   'of',
#   'address',
#   'system',
#   '.'),
#  '10008470_1_1': ('enter',
#   'information',
#   'from',
#   'your',
#   'current',
#   'license',
#   'to',
#   'login',
#   'to',
#   'the',
#   'service',
#   '.'),
#  '10008470_1_2': ('type', 'in', 'your', 'new', 'address', '.'),
#  '10008470_1_3': ('pay',
#   'a',
#   '$',
#   '25',
#   'fee',
#   'with',
#   'a',
#   'valid',
#   'credit',
#   'card',
#   '.'),
#  '10008470_1_4': ('print',
#   'a',
#   'temporary',
#   'license',
#   'to',
#   'use',
#   'until',
#   'your',
#   'new',
#   'license',
#   'arrives',
#   'by',
#   'mail',
#   '.'),
#  '10008621_0_0': ('read', 'the', 'ccj', 'carefully', '.'),
#  '10008621_0_1': ('pay',
#   'the',
#   'judgment',
#   'in',
#   'full',
#   'if',
#   'you',
#   'can',
#   '.'),
#  '10008621_0_2': ('pay', 'in', 'installments', '.'),
#  '10008621_1_0': ('draft', 'a', 'written', 'budget', '.'),
#  '10008621_1_1': ('write',
#   'a',
#   'letter',
#   'requesting',
#   'redetermination',
#   'if',
#   'possible',
#   '.'),
#  '10008621_1_2': ('fill',
#   'out',
#   'the',
#   'n245',
#   'application',
#   'form',
#   'to',
#   'vary',
#   'the',
#   'terms',
#   '.'),
#  '10008621_1_3': ('send', 'your', 'application', 'to', 'the', 'court', '.'),
#  '10008621_1_4': ('attend', 'a', 'court', 'hearing', '.'),
#  '10008621_1_5': ('make',
#   'the',
#   'payments',
#   'on',
#   'the',
#   'ccj',
#   'until',
#   'the',
#   'terms',
#   'are',
#   'changed',
#   '.'),
#  '10008621_2_0': ('evaluate',
#   'your',
#   'reasons',
#   'for',
#   'having',
#   'the',
#   'ccj',
#   'set',
#   'aside',
#   '.'),
#  '10008621_2_1': ('get',
#   'advice',
#   'and',
#   'assistance',
#   'from',
#   'a',
#   'debt',
#   'charity',
#   '.'),
#  '10008621_2_2': ('fill', 'out', 'the', 'application', 'notice', '.'),
#  '10008621_2_3': ('send', 'your', 'notice', 'to', 'the', 'court', '.'),
#  '10008621_2_4': ('go', 'to', 'your', 'private', 'hearing', '.'),
#  '10008621_2_5': ('work',
#   'with',
#   'the',
#   'creditor',
#   'to',
#   'repay',
#   'the',
#   'debt',
#   '.'),
#  '1000914_0_0': ('start',
#   'with',
#   'a',
#   'simple',
#   'sentence',
#   'describing',
#   'the',
#   'character',
#   '.'),
#  '1000914_0_1': ('write',
#   'down',
#   'the',
#   'character',
#   '’s',
#   'basic',
#   'life',
#   'statistics',
#   '.'),
#  '1000914_0_2': ('envision',
#   'the',
#   'character',
#   '’s',
#   'outward',
#   'appearance',
#   '.'),
#  '1000914_0_3': ('develop', 'mannerisms', 'for', 'the', 'character', '.'),
#  '1000914_0_4': ('name', 'your', 'character', '.'),
#  '1000914_1_0': ('decide',
#   'on',
#   'a',
#   'hometown',
#   'for',
#   'the',
#   'character',
#   '.'),
#  '1000914_1_1': ('plan', 'the', 'character', '’s', 'childhood', '.'),
#  '1000914_1_2': ('map',
#   'out',
#   'the',
#   'character',
#   '’s',
#   'personal',
#   'relationships',
#   '.'),
#  '1000914_1_3': ('build',
#   'the',
#   'character',
#   '’s',
#   'psychological',
#   'profile',
#   '.'),
#  '1000914_2_0': ('decide',
#   'if',
#   'this',
#   'character',
#   'will',
#   'experience',
#   'a',
#   'life',
#   '-',
#   'changing',
#   'event',
#   'in',
#   'the',
#   'story',
#   '.'),
#  '1000914_2_1': ('plan',
#   'if',
#   'this',
#   'character',
#   'will',
#   'be',
#   'a',
#   'protagonist',
#   'or',
#   'antagonist',
#   '.'),
#  '1000914_2_2': ('write',
#   'another',
#   'profile',
#   'if',
#   'the',
#   'character',
#   'will',
#   'age',
#   'in',
#   'the',
#   'story',
#   '.'),
#  '10009240_1_0': ('be',
#   'there',
#   'for',
#   'her',
#   'in',
#   '-',
#   'person',
#   'as',
#   'much',
#   'as',
#   'she',
#   'needs',
#   '.'),
#  '10009240_1_1': ('offer',
#   'to',
#   'help',
#   'her',
#   'with',
#   'anything',
#   'she',
#   'needs',
#   '.'),
#  '10009240_1_2': ('help',
#   'her',
#   'with',
#   'her',
#   'aftercare',
#   'medications',
#   'and',
#   'requirements',
#   '.'),
#  '10009240_1_3': ('offer',
#   'to',
#   'drive',
#   'her',
#   'to',
#   'follow',
#   '-',
#   'up',
#   'appointments',
#   '.'),
#  '10009240_1_4': ('make',
#   'her',
#   'a',
#   'care',
#   'package',
#   'of',
#   'her',
#   'favorite',
#   'things',
#   '.'),
#  '10009240_1_5': ('think',
#   'about',
#   'how',
#   'you',
#   'can',
#   'help',
#   'with',
#   'contraception',
#   'in',
#   'the',
#   'future',
#   '.'),
#  '10009240_2_0': ('think',
#   'about',
#   'your',
#   'own',
#   'feelings',
#   'about',
#   'the',
#   'abortion',
#   '.'),
#  '10009240_2_1': ('talk',
#   'to',
#   'her',
#   'about',
#   'how',
#   'you',
#   'feel',
#   'when',
#   'the',
#   'time',
#   'is',
#   'right',
#   '.'),
#  '10009240_2_2': ('reach', 'out', 'to', 'people', 'you', 'trust', '.'),
#  '10009240_2_3': ('remember',
#   'that',
#   'the',
#   'process',
#   'will',
#   'take',
#   'time',
#   'for',
#   'both',
#   'of',
#   'you',
#   '.'),
#  '10009557_1_0': ('apply',
#   'an',
#   'ice',
#   'pack',
#   'to',
#   'your',
#   'head',
#   'or',
#   'neck',
#   '.'),
#  '10009557_1_1': ('take', 'a', 'warm', 'bath', 'or', 'shower', '.'),
#  '10009557_1_2': ('practice',
#   'deep',
#   'breathing',
#   'or',
#   'relaxation',
#   'techniques',
#   '.'),
#  '10009557_1_3': ('avoid',
#   'additional',
#   'triggers',
#   'that',
#   'can',
#   'make',
#   'the',
#   'headache',
#   'worse',
#   '.'),
#  '10009789_0_0': ('discuss',
#   'your',
#   'symptoms',
#   'with',
#   'your',
#   'doctor',
#   '.'),
#  '10009789_0_1': ('ask',
#   'your',
#   'doctor',
#   'about',
#   'treating',
#   'ulcerative',
#   'colitis',
#   'with',
#   '5',
#   '-',
#   'aminosalicylic',
#   'acid',
#   '.'),
#  '10009789_0_2': ('take',
#   'an',
#   'over',
#   '-',
#   'the',
#   '-',
#   'counter',
#   'medication',
#   'to',
#   'control',
#   'diarrhea',
#   '.'),
#  '10009789_0_3': ('inquire',
#   'about',
#   'corticosteroids',
#   'for',
#   'temporary',
#   'treatment',
#   'of',
#   'your',
#   'flare',
#   '-',
#   'ups',
#   '.'),
#  '10009789_0_4': ('consider',
#   'immunosuppressants',
#   'if',
#   'other',
#   'treatments',
#   'do',
#   "n't",
#   'ease',
#   'your',
#   'symptoms',
#   '.'),
#  '10009789_1_0': ('steer', 'clear', 'of', 'high', 'fat', 'foods', '.'),
#  '10009789_1_1': ('avoid', 'consuming', 'dairy', 'products', '.'),
#  '10009789_1_2': ('reduce',
#   'your',
#   'intake',
#   'of',
#   'high',
#   '-',
#   'fiber',
#   'foods',
#   'if',
#   'they',
#   'trigger',
#   'flare',
#   '-',
#   'ups',
#   '.'),
#  '10009789_1_3': ('avoid',
#   'alcohol',
#   'and',
#   'caffeine',
#   ',',
#   'which',
#   'can',
#   'worsen',
#   'flare',
#   '-',
#   'up',
#   'symptoms',
#   '.'),
#  '10009789_2_0': ('go',
#   'for',
#   'regular',
#   'check',
#   '-',
#   'ups',
#   'with',
#   'your',
#   'doctor',
#   '.'),
#  '10009789_2_1': ('consult', 'a', 'dietician', 'or', 'nutritionist', '.'),
#  '10009789_2_2': ('keep', 'a', 'food', 'diary', '.'),
#  '10009789_2_3': ('eat', 'smaller', 'meals', 'during', 'the', 'day', '.'),
#  '10009910_0_0': ('plan',
#   'to',
#   'visit',
#   'between',
#   'tuesday',
#   'and',
#   'sunday',
#   'from',
#   '10',
#   'am',
#   'to',
#   '8',
#   'pm',
#   '.'),
#  '10009910_0_1': ('purchase',
#   'tickets',
#   'at',
#   'the',
#   'paris',
#   'catacombs',
#   'when',
#   'you',
#   'arrive',
#   '.'),
#  '10009910_0_2': ('book',
#   'tickets',
#   'in',
#   'advance',
#   'online',
#   'if',
#   'you',
#   'do',
#   "n't",
#   'want',
#   'to',
#   'wait',
#   'in',
#   'line',
#   '.'),
#  '10009910_0_3': ('purchase',
#   'tickets',
#   'in',
#   'advance',
#   'through',
#   'a',
#   'tour',
#   'company',
#   'to',
#   'skip',
#   'the',
#   'line',
#   '.'),
#  '10009910_1_0': ('travel',
#   'via',
#   'the',
#   'paris',
#   '38',
#   'and',
#   '68',
#   'bus',
#   'lines',
#   ',',
#   'which',
#   'stop',
#   'nearby',
#   '.'),
#  '10009910_1_1': ('ride',
#   'the',
#   'paris',
#   'metro',
#   'lines',
#   '4',
#   'or',
#   '6',
#   'to',
#   'travel',
#   'by',
#   'subway',
#   '.'),
#  '10009910_1_2': ('take',
#   'a',
#   'train',
#   'to',
#   'denfert',
#   '-',
#   'rochereau',
#   'railway',
#   'station',
#   'via',
#   'line',
#   'b.'),
#  '10009910_2_0': ('eat',
#   'a',
#   'good',
#   'meal',
#   'before',
#   'you',
#   'go',
#   'and',
#   'bring',
#   'water',
#   'for',
#   'hydration',
#   '.'),
#  '10009910_2_1': ('dress',
#   'warm',
#   'for',
#   'the',
#   'colder',
#   'temperatures',
#   '.'),
#  '10009910_2_2': ('do',
#   "n't",
#   'bring',
#   'anything',
#   'along',
#   'that',
#   'you',
#   'do',
#   "n't",
#   'want',
#   'to',
#   'carry',
#   '.'),
#  '10009910_2_3': ('use',
#   'the',
#   'restroom',
#   'before',
#   'you',
#   'enter',
#   'the',
#   'catacombs',
#   '.'),
#  '10009910_2_4': ('look',
#   'out',
#   'for',
#   'inscriptions',
#   'made',
#   'by',
#   'the',
#   'igc',
#   'crews',
#   '.'),
#  '10009910_2_5': ('examine', 'the', 'port', 'mahon', 'sculptures', '.'),
#  '10009910_2_6': ('explore',
#   'the',
#   'tunnels',
#   'housing',
#   'the',
#   'deceased',
#   'parisian',
#   'remains',
#   '.'),
#  '10009910_3_0': ('head',
#   'to',
#   'the',
#   'luxembourg',
#   'gardens',
#   'for',
#   'a',
#   'variety',
#   'of',
#   'activities',
#   '.'),
#  '10009910_3_1': ('visit',
#   'the',
#   'parisian',
#   'neighborhood',
#   'of',
#   'montparnasse',
#   '.'),
#  '10009910_3_2': ('explore', 'the', 'montparnasse', 'cemetery', '.'),
#  '10010791_0_0': ('stress',
#   'that',
#   'they',
#   'should',
#   'n’t',
#   'feel',
#   'guilty',
#   'about',
#   'loving',
#   'themselves',
#   '.'),
#  '10010791_0_1': ('tell',
#   'them',
#   'to',
#   'make',
#   'a',
#   'list',
#   'of',
#   'their',
#   'positive',
#   'qualities',
#   '.'),
#  '10010791_0_2': ('explain',
#   'that',
#   'self',
#   '-',
#   'esteem',
#   'should',
#   'n’t',
#   'be',
#   'based',
#   'on',
#   'others',
#   '’',
#   'opinions',
#   '.'),
#  '10010791_0_3': ('remind',
#   'them',
#   'that',
#   'they',
#   'should',
#   'n’t',
#   'compare',
#   'themselves',
#   'to',
#   'others',
#   '.'),
#  '10010791_0_4': ('encourage',
#   'them',
#   'to',
#   'help',
#   'others',
#   'and',
#   'volunteer',
#   'for',
#   'causes',
#   'they',
#   'value',
#   '.'),
#  '10010791_1_0': ('explain',
#   'how',
#   'to',
#   'identify',
#   'and',
#   'redirect',
#   'negative',
#   'self',
#   '-',
#   'talk',
#   '.'),
#  '10010791_1_1': ('remind',
#   'them',
#   'that',
#   'negative',
#   'situations',
#   'are',
#   'impermanent',
#   '.'),
#  '10010791_1_2': ('assure',
#   'your',
#   'loved',
#   'one',
#   'that',
#   'everyone',
#   'makes',
#   'mistakes',
#   '.'),
#  '10010791_1_3': ('ask',
#   'them',
#   'to',
#   'accept',
#   'things',
#   'that',
#   'are',
#   'beyond',
#   'their',
#   'control',
#   '.'),
#  '10010791_2_0': ('discuss',
#   'the',
#   'importance',
#   'of',
#   'a',
#   'strong',
#   'support',
#   'system',
#   '.'),
#  '10010791_2_1': ('give',
#   'them',
#   'tips',
#   'about',
#   'maintaining',
#   'their',
#   'overall',
#   'health',
#   '.'),
#  '10010791_2_2': ('suggest',
#   'that',
#   'they',
#   'pursue',
#   'activities',
#   'that',
#   'bring',
#   'them',
#   'joy',
#   '.'),
#  '10011164_0_0': ('request',
#   'a',
#   'transfer',
#   'of',
#   'your',
#   'child',
#   "'s",
#   'school',
#   'records',
#   '.'),
#  '10011164_0_1': ('attend',
#   'an',
#   'iep',
#   'meeting',
#   'at',
#   'your',
#   'child',
#   "'s",
#   'new',
#   'school',
#   '.'),
#  '10011164_0_2': ('make', 'any', 'necessary', 'adjustments', '.'),
#  '10011164_1_0': ('have',
#   'your',
#   'child',
#   "'s",
#   'current',
#   'school',
#   'transfer',
#   'records',
#   'to',
#   'the',
#   'new',
#   'school',
#   '.'),
#  '10011164_1_1': ('ask',
#   'your',
#   'child',
#   "'s",
#   'current',
#   'doctor',
#   'for',
#   'referrals',
#   '.'),
#  '10011164_1_2': ('discuss',
#   'your',
#   'child',
#   "'s",
#   'iep',
#   'with',
#   'staff',
#   'at',
#   'the',
#   'new',
#   'school',
#   '.'),
#  '10011164_1_3': ('update', 'your', 'child', "'s", 'iep', 'binder', '.'),
#  '10011164_2_0': ('get',
#   'complete',
#   'copies',
#   'of',
#   'your',
#   'child',
#   "'s",
#   'school',
#   'records',
#   '.'),
#  '10011164_2_1': ('contact',
#   'the',
#   'special',
#   'education',
#   'department',
#   'in',
#   'your',
#   'new',
#   'state',
#   '.'),
#  '10011164_2_2': ('find',
#   'the',
#   'nearest',
#   'parent',
#   'training',
#   'and',
#   'information',
#   'center',
#   '(',
#   'pti',
#   ')',
#   'in',
#   'your',
#   'new',
#   'state',
#   '.'),
#  '10011164_2_3': ('get',
#   'referrals',
#   'from',
#   'your',
#   'child',
#   "'s",
#   'doctors',
#   '.'),
#  '10011164_2_4': ('get',
#   'copies',
#   'of',
#   'your',
#   'child',
#   "'s",
#   'medical',
#   'reports',
#   'and',
#   'records',
#   '.'),
#  '10011164_2_5': ('set',
#   'up',
#   'any',
#   'necessary',
#   'evaluations',
#   'or',
#   'testing',
#   '.'),
#  '10011164_2_6': ('attend',
#   'the',
#   'iep',
#   'meeting',
#   'at',
#   'the',
#   'new',
#   'school',
#   '.'),
#  '10011164_2_7': ('organize',
#   'a',
#   'new',
#   'iep',
#   'binder',
#   'for',
#   'your',
#   'child',
#   '.'),
#  '100116_0_0': ('use', 'the', 'bagua', 'map', '.'),
#  '100116_0_1': ('examine',
#   'each',
#   'section',
#   'of',
#   'the',
#   'map',
#   'closely',
#   '.'),
#  '100116_0_2': ('apply', 'the', 'whole', 'map', '.'),
#  '100116_0_3': ('fix', 'things', 'that', 'are', 'broken', '.'),
#  '100116_0_4': ('use',
#   'the',
#   'five',
#   'elements',
#   'to',
#   'bring',
#   'balance',
#   '.'),
#  '100116_0_5': ('use', 'your', 'front', 'door', '.'),
#  '100116_0_6': ('hire', 'a', 'feng', 'shui', 'consultant', '.'),
#  '100116_1_0': ('remove', 'clutter', '.'),
#  '100116_1_1': ('position',
#   'your',
#   'bed',
#   'with',
#   'feet',
#   'toward',
#   'the',
#   'door',
#   '.'),
#  '100116_1_2': ('place',
#   'a',
#   'chest',
#   'or',
#   'bureau',
#   'opposite',
#   'the',
#   'bed',
#   '.'),
#  '100116_1_3': ('utilize', 'bedroom', 'windows', '.'),
#  '100116_2_0': ('fill', 'negative', 'space', 'above', 'cabinets', '.'),
#  '100116_2_1': ('fix', 'the', 'leaky', 'faucet', '.'),
#  '100116_2_2': ('clean', 'out', 'cabinets', 'regularly', '.'),
#  '100116_2_3': ('show', 'love', 'to', 'your', 'stove', '.'),
#  '10011864_0_0': ('discuss',
#   'pet',
#   'care',
#   'with',
#   'the',
#   'new',
#   'owner',
#   '.'),
#  '10011864_0_1': ('search',
#   'the',
#   'internet',
#   'for',
#   'templates',
#   'and',
#   'samples',
#   '.'),
#  '10011864_0_2': ('include',
#   'information',
#   'about',
#   'yourself',
#   'and',
#   'the',
#   'new',
#   'owner',
#   '.'),
#  '10011864_0_3': ('provide', 'details', 'about', 'the', 'pet', '.'),
#  '10011864_0_4': ('add',
#   'proper',
#   'disclaimers',
#   'and',
#   'choice',
#   'of',
#   'law',
#   '.'),
#  '10011864_0_5': ('sign', 'the', 'agreement', '.'),
#  '10011864_1_0': ('fill', 'out', 'a', 'license', 'transfer', 'form', '.'),
#  '10011864_1_1': ('sign',
#   'the',
#   'form',
#   'in',
#   'the',
#   'presence',
#   'of',
#   'a',
#   'notary',
#   'if',
#   'required',
#   '.'),
#  '10011864_1_2': ('submit',
#   'your',
#   'form',
#   'in',
#   'person',
#   'if',
#   'necessary',
#   '.'),
# ...
#   'front',
#   'teeth',
#   '.'),
#  '10024547_1_3': ('get',
#   'a',
#   'removable',
#   'complete',
#   'denture',
#   'to',
#   'replace',
#   'all',
#   'the',
#   'teeth',
#   'on',
#   'your',
#   'lower',
#   'or',
#   'upper',
#   'jaw',
#   '.'),
#  '10024547_2_0': ('take',
#   'your',
#   'dentures',
#   'in',
#   'for',
#   'an',
#   'adjustment',
#   'if',
#   'they',
#   'are',
#   'ill',
#   '-',
#   'fitting',
#   '.'),
#  '10024547_2_1': ('brush',
#   'your',
#   'removable',
#   'dentures',
#   'every',
#   'day',
#   '.'),
#  '10024547_2_2': ('never',
#   'attempt',
#   'to',
#   'adjust',
#   'or',
#   'repair',
#   'your',
#   'dentures',
#   'on',
#   'your',
#   'own',
#   '.'),
#  '100245_0_0': ('select', 'fimo', 'eberhard', 'faber', 'clay', '.'),
#  '100245_0_1': ('choose',
#   'promat',
#   'polyform',
#   'products',
#   'co.',
#   'clay',
#   '.'),
#  '100245_0_2': ('opt', 'for', 'cernit', 't&f', 'gmbh', 'clay', '.'),
#  '100245_3_0': ('decorate',
#   'fresh',
#   'clay',
#   'creations',
#   'with',
#   'your',
#   'fired',
#   'rose',
#   '.'),
#  '100245_3_1': ('make', 'a', 'refrigerator', 'magnet', '.'),
#  '100245_3_2': ('create', 'your', 'own', 'jewelry', '.'),
#  '10024772_0_0': ('wrap',
#   'a',
#   'scarf',
#   'around',
#   'your',
#   'upper',
#   'scalp',
#   '.'),
#  '10024772_0_1': ('apply',
#   'a',
#   'loose',
#   '-',
#   'fitting',
#   'bandage',
#   'to',
#   'the',
#   'infected',
#   'area',
#   '.'),
#  '10024772_0_2': ('leave',
#   'it',
#   'uncovered',
#   'as',
#   'often',
#   'as',
#   'possible',
#   '.'),
#  '10024772_1_0': ('talk',
#   'with',
#   'your',
#   'doctor',
#   'before',
#   'applying',
#   'makeup',
#   'to',
#   'your',
#   'ringworm',
#   '.'),
#  '10024772_1_1': ('apply',
#   'a',
#   'moisturizer',
#   'primer',
#   'or',
#   'face',
#   'cream',
#   'on',
#   'to',
#   'your',
#   'skin',
#   '.'),
#  '10024772_1_2': ('rub',
#   'concealer',
#   'on',
#   'to',
#   'your',
#   'face',
#   'using',
#   'your',
#   'fingertips',
#   '.'),
#  '10024772_1_3': ('cover',
#   'your',
#   'face',
#   'in',
#   'foundation',
#   'using',
#   'a',
#   'brush',
#   '.'),
#  '10024772_1_4': ('remove', 'makeup', 'carefully', 'using', 'wipes', '.'),
#  '10024772_2_0': ('take',
#   'a',
#   'prescription',
#   'antifungal',
#   'medication',
#   'for',
#   'up',
#   'to',
#   '8',
#   'weeks',
#   '.'),
#  '10024772_2_1': ('use',
#   'an',
#   'antifungal',
#   'shampoo',
#   'for',
#   'up',
#   'to',
#   '8',
#   'weeks',
#   '.'),
#  '10024772_2_2': ('seek',
#   'additional',
#   'treatment',
#   'if',
#   'you',
#   'develop',
#   'swelling',
#   'around',
#   'the',
#   'ringworm',
#   '.'),
#  '10025040_0_0': ('look',
#   'at',
#   'the',
#   'situation',
#   'from',
#   'their',
#   'perspective',
#   '.'),
#  '10025040_0_1': ('consider',
#   'whether',
#   'there',
#   'are',
#   'other',
#   'factors',
#   'making',
#   'someone',
#   'upset',
#   '.'),
#  '10025040_0_2': ('stay', 'calm', '.'),
#  '10025040_0_3': ('prepare', 'for', 'their', 'negative', 'attitude', '.'),
#  '10025040_0_4': ('practice',
#   'kindness',
#   'even',
#   'when',
#   'it',
#   '’s',
#   'difficult',
#   '.'),
#  '10025040_1_0': ('have',
#   'an',
#   'honest',
#   'discussion',
#   'about',
#   'your',
#   'feelings',
#   '.'),
#  '10025040_1_1': ('look',
#   'at',
#   'things',
#   'from',
#   'their',
#   'point',
#   'of',
#   'view',
#   '.'),
#  '10025040_1_2': ('set',
#   'up',
#   'boundaries',
#   'that',
#   'state',
#   'what',
#   'you',
#   'will',
#   'and',
#   'wo',
#   'n’t',
#   'do',
#   '.'),
#  '10025040_1_3': ('cut',
#   'ties',
#   'with',
#   'the',
#   'person',
#   'if',
#   'they',
#   'are',
#   'constantly',
#   'negative',
#   '.'),
#  '10025040_2_0': ('give',
#   'honest',
#   'thanks',
#   'for',
#   'everyday',
#   'things',
#   '.'),
#  '10025040_2_1': ('encourage', 'a', 'culture', 'of', 'gratitude', '.'),
#  '10025040_2_2': ('keep', 'a', 'gratitude', 'journal', '.'),
#  '10025057_0_0': ('read',
#   'about',
#   'hunger',
#   'in',
#   'the',
#   'us',
#   'for',
#   'up',
#   '-',
#   'to',
#   '-',
#   'date',
#   'information',
#   '.'),
#  '10025057_0_1': ('spread',
#   'the',
#   'word',
#   'to',
#   'friends',
#   'and',
#   'family',
#   'to',
#   'encourage',
#   'them',
#   'to',
#   'help',
#   '.'),
#  '10025057_0_2': ('use',
#   'social',
#   'media',
#   'to',
#   'inform',
#   'others',
#   'about',
#   'the',
#   'problem',
#   'of',
#   'hunger',
#   '.'),
#  '10025057_0_3': ('organize',
#   'a',
#   'bake',
#   'sale',
#   'or',
#   'run',
#   'to',
#   'raise',
#   'awareness',
#   '.'),
#  '10025057_0_4': ('start',
#   'a',
#   'letter',
#   'campaign',
#   'to',
#   'encourage',
#   'others',
#   'to',
#   'write',
#   'to',
#   'local',
#   'lawmakers',
#   '.'),
#  '10025057_0_5': ('host',
#   'a',
#   'movie',
#   'screening',
#   'showing',
#   'a',
#   'movie',
#   'about',
#   'hunger',
#   'in',
#   'the',
#   'us',
#   '.'),
#  '10025057_1_0': ('donate',
#   'excess',
#   'food',
#   'in',
#   'your',
#   'home',
#   'to',
#   'an',
#   'organization',
#   '.'),
#  '10025057_1_1': ('contact',
#   'your',
#   'local',
#   'food',
#   'bank',
#   'to',
#   'learn',
#   'about',
#   'volunteer',
#   'opportunities',
#   '.'),
#  '10025057_1_2': ('host',
#   'a',
#   'healthy',
#   'food',
#   'drive',
#   'in',
#   'your',
#   'area',
#   '.'),
#  '10025057_1_3': ('set',
#   'up',
#   'an',
#   'online',
#   'food',
#   'drive',
#   'to',
#   'easily',
#   'collect',
#   'food',
#   '.'),
#  '10025057_1_4': ('help', 'grow', 'food', 'locally', '.'),
#  '10025057_1_5': ('volunteer',
#   'throughout',
#   'the',
#   'year',
#   ',',
#   'not',
#   'just',
#   'during',
#   'winter',
#   'holidays',
#   '.'),
#  '10025057_2_0': ('contribute',
#   'to',
#   'feeding',
#   'america',
#   'to',
#   'provide',
#   'meals',
#   'to',
#   'the',
#   'hungry',
#   '.'),
#  '10025057_2_1': ('donate',
#   'to',
#   'meals',
#   'on',
#   'wheels',
#   'to',
#   'promote',
#   'the',
#   'delivery',
#   'of',
#   'food',
#   '.'),
#  '10025057_2_2': ('visit',
#   'feed',
#   'the',
#   'children',
#   '’s',
#   'website',
#   'to',
#   'make',
#   'a',
#   'difference',
#   'in',
#   'children',
#   '’s',
#   'lives',
#   '.'),
#  '10025057_2_3': ('support',
#   'no',
#   'kid',
#   'hungry',
#   'in',
#   'their',
#   'goal',
#   'to',
#   'reduce',
#   'children',
#   '’s',
#   'hunger',
#   '.'),
#  '10025057_2_4': ('help',
#   'unicef',
#   'save',
#   'children',
#   'from',
#   'experiencing',
#   'hunger',
#   '.'),
#  '100250_0_0': ('prepare',
#   'your',
#   'empty',
#   'pill',
#   'bottle',
#   'for',
#   'use',
#   '.'),
#  '100250_0_1': ('keep',
#   'your',
#   'office',
#   'items',
#   'in',
#   'empty',
#   'pill',
#   'bottles',
#   '.'),
#  '100250_0_2': ('hide', 'a', 'spare', 'key', 'in', 'the', 'container', '.'),
#  '100250_0_3': ('store',
#   'jewelry',
#   'and',
#   'cosmetic',
#   'items',
#   'in',
#   'the',
#   'pill',
#   'bottle',
#   '.'),
#  '100250_0_4': ('place',
#   'your',
#   'cotton',
#   'swabs',
#   'in',
#   'the',
#   'pill',
#   'bottle',
#   '.'),
#  '100250_0_5': ('fill',
#   'your',
#   'empty',
#   'pill',
#   'bottles',
#   'with',
#   'lotion',
#   'for',
#   'traveling',
#   '.'),
#  '100250_0_6': ('stash',
#   'your',
#   'earbuds',
#   'in',
#   'an',
#   'empty',
#   'pill',
#   'bottle',
#   '.'),
#  '100250_0_7': ('store',
#   'seeds',
#   'in',
#   'your',
#   'empty',
#   'pill',
#   'bottles',
#   '.'),
#  '100250_0_8': ('organize', 'your', 'piping', 'tips', '.'),
#  '100250_0_9': ('craft', 'a', 'portable', 'sewing', 'kit', '.'),
#  '100250_0_10': ('carry', 'matches', 'in', 'the', 'pill', 'bottle', '.'),
#  '100250_0_11': ('make', 'a', 'coin', 'container', '.'),
#  '100250_0_12': ('make', 'a', 'fire', 'starter', '.'),
#  '100250_1_0': ('make', 'a', 'nail', 'polish', 'remover', 'tub', '.'),
#  '100250_1_1': ('make', 'some', 'jumbo', 'crayons', '.'),
#  '100250_1_2': ('make', 'a', 'candle', 'holder', '.'),
#  '100250_1_3': ('write',
#   'a',
#   'love',
#   'medication',
#   'for',
#   'your',
#   'partner',
#   '.'),
#  '100250_2_0': ('give', 'the', 'caroler', 'a', 'head', '.'),
#  '100250_2_1': ('create', 'the', 'figure', '’s', 'arms', '.'),
#  '100250_2_2': ('clothe', 'the', 'caroler', '.'),
#  '100250_2_3': ('place',
#   'a',
#   'songbook',
#   'in',
#   'the',
#   'caroler',
#   '’s',
#   'arms',
#   '.'),
#  '10025431_0_0': ('remove',
#   'clutter',
#   'and',
#   'unnecessary',
#   'items',
#   'from',
#   'the',
#   'car',
#   '.'),
#  '10025431_0_1': ('clean', 'and', 'vacuum', 'your', 'car', 'thoroughly', '.'),
#  '10025431_0_2': ('ensure', 'your', 'car', 'doors', 'seal', 'tightly', '.'),
#  '10025431_0_3': ('do',
#   'not',
#   'leave',
#   'your',
#   'car',
#   'idling',
#   'for',
#   'long',
#   'periods',
#   'of',
#   'time',
#   '.'),
#  '10025431_1_0': ('mix',
#   'an',
#   'essential',
#   'oil',
#   'spray',
#   'to',
#   'ward',
#   'off',
#   'spiders',
#   'naturally',
#   '.'),
#  '10025431_1_1': ('spread',
#   'eucalyptus',
#   'leaves',
#   'around',
#   'your',
#   'car',
#   'as',
#   'a',
#   'non',
#   '-toxic',
#   'repellant',
#   '.'),
#  '10025431_1_2': ('spray',
#   'a',
#   'non',
#   '-toxic',
#   'spider',
#   'repellant',
#   'in',
#   'your',
#   'car',
#   'to',
#   'get',
#   'rid',
#   'of',
#   'spiders',
#   'quickly',
#   '.'),
#  '10025431_2_0': ('catch',
#   'and',
#   'get',
#   'rid',
#   'of',
#   'any',
#   'existing',
#   'spiders',
#   'in',
#   'your',
#   'car',
#   '.'),
#  '10025431_2_1': ('vacuum', 'your', 'entire', 'car', '.'),
#  '10025431_2_2': ('turn',
#   'off',
#   'your',
#   'interior',
#   'car',
#   'lights',
#   'while',
#   'using',
#   'your',
#   'car',
#   '.'),
#  '10025431_2_3': ('fix',
#   'any',
#   'cracks',
#   'or',
#   'holes',
#   'in',
#   'your',
#   'car',
#   'so',
#   'spiders',
#   "can't",
#   'get',
#   'in',
#   'it',
#   '.'),
#  '10025950_0_0': ('opt',
#   'for',
#   'blind',
#   'rivets',
#   'instead',
#   'of',
#   'solid',
#   'rivets',
#   '.'),
#  '10025950_0_1': ('select',
#   'multi-grip',
#   'rivets',
#   'for',
#   'situations',
#   'that',
#   'require',
#   'high',
#   '-',
#   'strength',
#   'fastening',
#   '.'),
#  '10025950_0_2': ('purchase',
#   'sealed',
#   'rivets',
#   'when',
#   'you',
#   'need',
#   'a',
#   'tight',
#   'seal',
#   'that',
#   'resists',
#   'leaking',
#   '.'),
#  '10025950_0_3': ('select',
#   'interlock',
#   'rivets',
#   'for',
#   'situations',
#   'that',
#   'require',
#   'high',
#   '-',
#   'strength',
#   'fastening',
#   '.'),
#  '10025950_0_4': ('purchase',
#   'dome',
#   'head',
#   'rivets',
#   'for',
#   'standard',
#   'materials',
#   'and',
#   'situations',
#   '.'),
#  '10025950_0_5': ('opt',
#   'for',
#   'flat',
#   'head',
#   'rivets',
#   'to',
#   'ensure',
#   'a',
#   'flush',
#   ',',
#   'tight',
#   'fit',
#   '.'),
#  '10025950_0_6': ('select',
#   'a',
#   'rivet',
#   'made',
#   'from',
#   'the',
#   'same',
#   'material',
#   'as',
#   'the',
#   'metal',
#   'you',
#   "'re",
#   'joining',
#   '.'),
#  '10025950_1_0': ('drill',
#   'a',
#   'rivet',
#   'hole',
#   'using',
#   'a',
#   'standard',
#   'twist',
#   'drill',
#   '.'),
#  '10025950_1_1': ('select',
#   'a',
#   'rivet',
#   'size',
#   'suitable',
#   'for',
#   'your',
#   'materials',
#   '.'),
#  '10025950_1_2': ('attach',
#   'the',
#   'proper',
#   'nozzle',
#   'attachment',
#   'tip',
#   'based',
#   'on',
#   'your',
#   'rivet',
#   'size',
#   '.'),
#  '10025950_1_3': ('slide',
#   'the',
#   'rivet',
#   'long',
#   '-',
#   'side',
#   'first',
#   'into',
#   'the',
#   'nozzle',
#   'of',
#   'your',
#   'gun',
#   '.'),
#  '10025950_1_4': ('place',
#   'the',
#   'rivet',
#   'through',
#   'both',
#   'materials',
#   'and',
#   'press',
#   'the',
#   'gun',
#   'against',
#   'it',
#   '.'),
#  '10025950_1_5': ('squeeze',
#   'the',
#   'handle',
#   'trigger',
#   'of',
#   'the',
#   'gun',
#   'until',
#   'the',
#   'rivet',
#   'attaches',
#   '.'),
#  '10025950_2_0': ('drill',
#   'a',
#   'hole',
#   'for',
#   'your',
#   'rivet',
#   'with',
#   'a',
#   'standard',
#   'twist',
#   'drill',
#   '.'),
#  '10025950_2_1': ('purchase',
#   'solid',
#   'rivets',
#   'that',
#   'match',
#   'the',
#   'size',
#   'of',
#   'the',
#   'drill',
#   'hole',
#   '.'),
#  '10025950_2_2': ('opt',
#   'for',
#   'a',
#   'slow',
#   '-',
#   'hitting',
#   'gun',
#   'for',
#   'medium',
#   '-',
#   'sized',
#   'rivets',
#   '.'),
#  '10025950_2_3': ('select',
#   'a',
#   'fast',
#   '-',
#   'hitting',
#   'gun',
#   'when',
#   'using',
#   'soft',
#   'rivets',
#   '.'),
#  '10025950_2_4': ('purchase',
#   'a',
#   'one',
#   '-',
#   'shot',
#   'gun',
#   'if',
#   'you',
#   "'re",
#   'working',
#   'with',
#   'heavy',
#   '-',
#   'gauge',
#   'metals',
#   '.'),
#  '10025950_2_5': ('set',
#   'your',
#   'rivet',
#   "gun's",
#   'air',
#   'pressure',
#   'to',
#   'match',
#   'your',
#   'rivet',
#   'size',
#   '.'),
#  '10025950_2_6': ('attach',
#   'a',
#   'cup',
#   'set',
#   'that',
#   'matches',
#   'your',
#   'rivet',
#   '.'),
#  '10025950_2_7': ('insert',
#   'the',
#   'rivet',
#   'through',
#   'its',
#   'hole',
#   'and',
#   'hold',
#   'it',
#   'in',
#   'place',
#   'with',
#   'the',
#   'tip',
#   'of',
#   'the',
#   'cup',
#   'set',
#   '.'),
#  '10025950_2_8': ('hold',
#   'a',
#   'bucking',
#   'bar',
#   'against',
#   'the',
#   'shop',
#   'head',
#   'of',
#   'the',
#   'rivet',
#   'to',
#   'absorb',
#   'impact',
#   '.'),
#  '10025950_2_9': ('engage',
#   'the',
#   'gun',
#   'squarely',
#   'with',
#   'the',
#   'rivet',
#   'head',
#   'and',
#   'squeeze',
#   'the',
#   'trigger',
#   '.'),
#  '100263_0_0': ('hold',
#   'your',
#   'head',
#   'up',
#   'high',
#   'and',
#   'look',
#   'forward',
#   '.'),
#  '100263_0_1': ('keep',
#   'your',
#   'shoulders',
#   'level',
#   'and',
#   'straight',
#   'by',
#   'rolling',
#   'them',
#   'back',
#   '.'),
#  '100263_0_2': ('stick',
#   'your',
#   'chest',
#   'outward',
#   'a',
#   'bit',
#   ',',
#   'and',
#   'make',
#   'your',
#   'stomach',
#   'slightly',
#   'flat',
#   '.'),
#  '100263_0_3': ('keep',
#   'your',
#   'back',
#   'straight',
#   ',',
#   'but',
#   'not',
#   'stiff',
#   '.'),
#  '100263_1_0': ('sit',
#   'squarely',
#   'in',
#   'the',
#   'saddle',
#   ',',
#   'and',
#   'put',
#   'weight',
#   'on',
#   'both',
#   'of',
#   'your',
#   'seat',
#   'bones',
#   '.'),
#  '100263_1_1': ('keep',
#   'your',
#   'legs',
#   'handing',
#   'close',
#   'to',
#   'your',
#   'horse',
#   "'s",
#   'side',
#   ',',
#   'without',
#   'gripping',
#   'at',
#   'the',
#   'knee',
#   '.'),
#  '100263_1_2': ('rest',
#   'the',
#   'balls',
#   'of',
#   'your',
#   'feet',
#   'on',
#   'the',
#   'tread',
#   'of',
#   'the',
#   'stirrup',
#   '.'),
#  '10029102_0_0': ('reach',
#   'out',
#   'to',
#   'a',
#   'friend',
#   'who',
#   'you',
#   'know',
#   'is',
#   'having',
#   'a',
#   'tough',
#   'time',
#   '.'),
#  '10029102_0_1': ('do',
#   'random',
#   'acts',
#   'of',
#   'kindness',
#   'to',
#   'encourage',
#   'positivity',
#   'and',
#   'happiness',
#   '.'),
#  '10029102_0_2': ('attend',
#   'at',
#   'a',
#   'local',
#   'mental',
#   'health',
#   'day',
#   'event',
#   '.'),
#  '10029102_0_3': ('donate',
#   'to',
#   'a',
#   'mental',
#   'health',
#   'charity',
#   'if',
#   'you',
#   'have',
#   'the',
#   'money',
#   'or',
#   'the',
#   'time',
#   '.'),
#  '10029102_1_0': ('read',
#   'and',
#   'share',
#   'an',
#   'article',
#   'about',
#   'mental',
#   'health',
#   '.'),
#  '10029102_1_1': ('write',
#   'your',
#   'story',
#   'on',
#   'the',
#   'computer',
#   'and',
#   'share',
#   'it',
#   'to',
#   'mental',
#   'health',
#   'blogs',
#   '.'),
#  '10029102_1_2': ('follow',
#   'mental',
#   'health',
#   'advocacy',
#   'organizations',
#   'on',
#   'social',
#   'media',
#   '.'),
#  '10029102_1_3': ('host',
#   'a',
#   'sharing',
#   'event',
#   'to',
#   'bring',
#   'your',
#   'friends',
#   'and',
#   'family',
#   'together',
#   '.'),
#  '10029102_1_4': ('hang',
#   'posters',
#   'about',
#   'mental',
#   'health',
#   'around',
#   'town',
#   'to',
#   'spread',
#   'awareness',
#   '.'),
#  '10029102_2_0': ('make',
#   'a',
#   'pledge',
#   'to',
#   'yourself',
#   'to',
#   'make',
#   'mental',
#   'health',
#   'a',
#   'priority',
#   'every',
#   'day',
#   '.'),
#  '10029102_2_1': ('meditate',
#   'for',
#   '5',
#   '-',
#   '20',
#   'minutes',
#   'to',
#   'set',
#   'aside',
#   'some',
#   'self',
#   '-',
#   'care',
#   '.'),
#  '10029102_2_2': ('take',
#   'a',
#   'yoga',
#   'class',
#   'to',
#   'rid',
#   'yourself',
#   'of',
#   'stress',
#   'and',
#   'worries',
#   '.'),
#  '10029102_2_3': ('go',
#   'on',
#   'a',
#   'stroll',
#   'through',
#   'a',
#   'local',
#   'state',
#   'park',
#   'to',
#   'encourage',
#   'a',
#   'positive',
#   'mood',
#   '.'),
#  '10029102_2_4': ('have',
#   'a',
#   'spa',
#   'day',
#   'at',
#   'home',
#   'if',
#   'you',
#   'are',
#   'in',
#   'need',
#   'of',
#   'relaxation',
#   '.'),
#  '10029102_2_5': ('watch',
#   'your',
#   'favorite',
#   'feel',
#   '-',
#   'good',
#   'movie',
#   'if',
#   'you',
#   'want',
#   'a',
#   'fun',
#   ',',
#   'relaxing',
#   'activity',
#   '.'),
#  '10029102_2_6': ('treat',
#   'yourself',
#   'to',
#   'a',
#   'shopping',
#   'trip',
#   'if',
#   'you',
#   'want',
#   'to',
#   'have',
#   'some',
#   'fun',
#   '.'),
#  '10029103_0_0': ('get', 'a', 'reference', 'image', '.'),
#  '10029103_0_1': ('draw',
#   'yourself',
#   'some',
#   'guidelines',
#   'to',
#   'build',
#   'the',
#   'flower',
#   'out',
#   'of',
#   '.'),
#  '10029103_0_2': ('notate',
#   'the',
#   'direction',
#   'of',
#   'the',
#   'petals',
#   'with',
#   'a',
#   'few',
#   'light',
#   'lines',
#   '.'),
#  '10029103_0_3': ('draw',
#   'oblong',
#   'shapes',
#   'around',
#   'those',
#   'lines',
#   'to',
#   'give',
#   'the',
#   'petals',
#   'some',
#   'thickness',
#   '.'),
#  '10029103_0_4': ('create',
#   'some',
#   'lines',
#   'to',
#   'show',
#   'the',
#   'pistil',
#   'and',
#   'the',
#   'stamen',
#   '.'),
#  ...}

# %%
### Get quadruples from the dependency trees generated from step headlines. ###
# Load the merged step_parses_all.p file.
step_parses = pickle.load(open(deptree_path + '/step_parsing/step_parsing_results/step_parses_all.p', 'rb'))

# %%
# Create a mapping from step_id to quadruple extracted from the headline of that step.
sid2quadruple = dict()
for sid in tqdm(step_parses):
    deptree = step_parses[sid].sentences[0]
    if sid not in sid2quadruple:
        sid2quadruple[sid] = get_quadruple(deptree)
        
for sid, values in list(sid2quadruple.items()):
#     print("BEFORE:", sid, values)
    values[1] = [item for sublist in values[1] for item in sublist]
#     print("AFTER:", sid, values, "\n")
        
# for sid in sid2quadruple:
#     sid2quadruple[sid] = list(sid2quadruple[sid])
#     for i, word in enumerate(sid2quadruple[sid][0]):
#         sid2quadruple[sid][0][i] = word.strip()
        
# for fid, values in list(sid2quadruple.items()):
#     print("BEFORE:", fid, values)
#     tmp = []
#     for sublist in values[1]:
#         tmp += sublist
#     values[1] = tmp
#     print("AFTER:", fid, values, "\n")
#     sid2quadruple[fid][1] = values[1]
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 772221/772221 [00:33<00:00, 22948.94it/s]

# %%
for i, values in list(sid2quadruple.items()):
    items = " ".join(values[0]).split()
#     print("ITEMS:", items)
    if len(items) != len(values[1]):
        print(i, values)
        l1, l2 = values[0][:2], values[0][-2:]
        l3, l4 = values[1][:2], values[1][-2:]
        for i, item in enumerate(l2):
            if item != '[PAD]':
                l2[i] = '[PAD]'
        l4 = [-1, -1]
        # words
        values[0] = l1 + l2
        # indices
        values[1] = l3 + l4
        print("l1:", l1, "l2:", l2, "l3:", l3, "l4:", l4)
        print("AFTER:", i, values, '\n')
# Out:
# 10002000_1_2 [['<|startoftext|>', 'let', 'or activity', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'let'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'let', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 1000676_1_3 [['<|startoftext|>', 'continue', 'and vegetables', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'continue'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'continue', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10024314_2_2 [['<|startoftext|>', 'continue', 'and activities', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'continue'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'continue', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10030143_0_2 [['<|startoftext|>', 'stop', 'or herb', ' by doctor'], [0, 1, 12, 14]]
# l1: ['<|startoftext|>', 'stop'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'stop', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 100340_1_1 [['<|startoftext|>', 'avoid', 'or clothes', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'avoid'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'avoid', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 1003798_0_1 [['<|startoftext|>', 'make', 'and conditioner', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'make'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'make', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10044817_0_6 [['<|startoftext|>', 'pack but forget', 'and layers', '[PAD]'], [0, 1, 3, 6, -1]]
# l1: ['<|startoftext|>', 'pack but forget'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'pack but forget', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10049169_0_0 [['<|startoftext|>', 'choose', 'or dye', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'choose'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'choose', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10070395_0_1 [['<|startoftext|>', 'dress', 'and atmosphere', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'dress'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'dress', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10084503_0_2 [['<|startoftext|>', 'ensure', 'and visas', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'ensure'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'ensure', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10085027_1_1 [['<|startoftext|>', 'try', 'and chewing', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'try'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'try', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 1009378_1_4 [['<|startoftext|>', 'prick', 'or forkholes', ' into skin of sausage'], [0, 8, 11, 12, 14, 15, 17]]
# l1: ['<|startoftext|>', 'prick'] l2: ['[PAD]', '[PAD]'] l3: [0, 8] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'prick', '[PAD]', '[PAD]'], [0, 8, -1, -1]]
#
# 10110515_1_2 [['<|startoftext|>', 'suggest', 'and achievements', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'suggest'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'suggest', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10121_1_1 [['<|startoftext|>', 'ensure', 'and end', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'ensure'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'ensure', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10136095_0_4 [['<|startoftext|>', 'let', 'or stencils', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'let'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'let', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10156_0_1 [['<|startoftext|>', 'avoid', 'or peroxide', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'avoid'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'avoid', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 101653_0_4 [['<|startoftext|>', 'make', 'and garbage', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'make'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'make', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 1017139_1_0 [['<|startoftext|>', 'fix', 'or ovensandwich  or pocket and stick', ' for lunch in half'], [0, 18, 15, 13, 14, 16, 21, 22, 25, 36, 39, 27, 28]]
# l1: ['<|startoftext|>', 'fix'] l2: ['[PAD]', '[PAD]'] l3: [0, 18] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'fix', '[PAD]', '[PAD]'], [0, 18, -1, -1]]
#
# 10184332_0_6 [['<|startoftext|>', 'alternate', 'and milk', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'alternate'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'alternate', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 1019718_1_3 [['<|startoftext|>', 'avoid', 'and disease', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'avoid'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'avoid', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10207657_2_4 [['<|startoftext|>', 'help', 'and suffixes', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'help'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'help', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10208770_2_1 [['<|startoftext|>', 'check', 'and conclusion', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'check'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'check', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10218591_0_4 [['<|startoftext|>', 'make', 'and skills', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'make'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'make', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10223563_0_4 [['<|startoftext|>', 'choose', 'or peptides', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'choose'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'choose', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10240799_0_2 [['<|startoftext|>', 'avoid', 'or eye', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'avoid'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'avoid', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10240801_1_0 [['<|startoftext|>', 'walk', 'and history', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'walk'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'walk', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10252347_2_4 [['<|startoftext|>', 'get', 'and ulcerations', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'get'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'get', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10256409_4_0 [['<|startoftext|>', 'ensure', 'and size', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'ensure'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'ensure', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10258531_0_1 [['<|startoftext|>', 'avoid', 'or products', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'avoid'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'avoid', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 1026312_2_2 [['<|startoftext|>', 'consider', '[PAD]', ' services or classes'], [0, 1, 5, -1]]
# l1: ['<|startoftext|>', 'consider'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'consider', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 102652_1_0 [['<|startoftext|>', 'open', 'or lock', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'open'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'open', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10273599_1_5 [['<|startoftext|>', 'offer', 'or concerns', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'offer'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'offer', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10279307_0_2 [['<|startoftext|>', 'avoid', 'and salt', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'avoid'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'avoid', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10279307_1_1 [['<|startoftext|>', 'avoid', 'and drugs', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'avoid'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'avoid', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10279634_0_7 [['<|startoftext|>', 'have', 'and report', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'have'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'have', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10279950_1_1 [['<|startoftext|>', 'avoid', 'or enclosures', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'avoid'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'avoid', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 1029392_0_2 [['<|startoftext|>', 'decide', 'or kitten', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'decide'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'decide', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10305904_2_2 [['<|startoftext|>', 'stay', 'or asthma', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'stay'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'stay', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10322295_0_3 [['<|startoftext|>', 'try', 'and arms', ' from keystone'], [0, 1, 9, 11]]
# l1: ['<|startoftext|>', 'try'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'try', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10334371_0_4 [['<|startoftext|>', 'turn and wash', 'and legs', '[PAD]'], [0, 1, 3, 4, -1]]
# l1: ['<|startoftext|>', 'turn and wash'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'turn and wash', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10353645_0_0 [['<|startoftext|>', 'work', 'or baseboards', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'work'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'work', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 1036148_0_4 [['<|startoftext|>', 'avoid', 'or deodorant', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'avoid'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'avoid', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 1036152_1_2 [['<|startoftext|>', 'avoid', 'and wasps', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'avoid'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'avoid', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10372026_1_0 [['<|startoftext|>', 'practice', 'and family', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'practice'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'practice', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10372071_1_5 [['<|startoftext|>', 'check', 'or shoes', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'check'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'check', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 1041078_1_1 [['<|startoftext|>', 'try', 'and treatments', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'try'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'try', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10415503_1_2 [['<|startoftext|>', 'try', 'and paperclips', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'try'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'try', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10417693_1_1 [['<|startoftext|>', 'learn', 'and gifts', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'learn'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'learn', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 1046081_3_0 [['<|startoftext|>', 'let', 'or vegetable', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'let'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'let', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 1047825_1_3 [['<|startoftext|>', 'make', 'and water', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'make'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'make', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 104907_2_1 [['<|startoftext|>', 'decide', 'and abilities', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'decide'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'decide', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 1050943_0_0 [['<|startoftext|>', 'recognize', 'and consistency', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'recognize'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'recognize', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 1052014_1_1 [['<|startoftext|>', 'decide', 'or attachment', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'decide'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'decide', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 1053606_1_4 [['<|startoftext|>', 'note', 'position', ' storm or event before of control'], [0, 11, 3, 1, 13, 14, 20]]
# l1: ['<|startoftext|>', 'note'] l2: ['[PAD]', '[PAD]'] l3: [0, 11] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'note', '[PAD]', '[PAD]'], [0, 11, -1, -1]]
#
# 105389_3_2 [['<|startoftext|>', 'stop', 'or discomfort', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'stop'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'stop', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 1054066_3_3 [['<|startoftext|>', 'see', 'or sauna', ' for you'], [0, 1, 10, 11]]
# l1: ['<|startoftext|>', 'see'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'see', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10544_3_1 [['<|startoftext|>', 'avoid', 'and agents', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'avoid'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'avoid', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10545458_2_3 [['<|startoftext|>', 'volunteer', 'and connections', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'volunteer'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'volunteer', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 1054667_0_2 [['<|startoftext|>', 'check', 'or amenities', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'check'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'check', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10547_1_3 [['<|startoftext|>', 'try', 'or distraction', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'try'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'try', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 1054875_0_5 [['<|startoftext|>', 'spray', '[PAD]', ' spray or cologne'], [0, 1, 5, -1]]
# l1: ['<|startoftext|>', 'spray'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'spray', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 1055915_2_2 [['<|startoftext|>', 'avoid', 'or staples', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'avoid'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'avoid', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 1057624_0_1 [['<|startoftext|>', 'determine', 'or law', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'determine'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'determine', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10576_0_14 [['<|startoftext|>', 'consider', 'or cat', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'consider'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'consider', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 1059578_3_0 [['<|startoftext|>', 'make', 'or adapters', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'make'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'make', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 105981_1_1 [['<|startoftext|>', 'opt', 'or phone', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'opt'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'opt', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10606585_1_3 [['<|startoftext|>', 'start', 'and help', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'start'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'start', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 1066106_0_1 [['<|startoftext|>', 'determine', 'and warnings', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'determine'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'determine', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10664260_0_3 [['<|startoftext|>', 'try', 'and pepper', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'try'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'try', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 106762_1_2 [['<|startoftext|>', 'avoid', 'and chants', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'avoid'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'avoid', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 1068183_3_7 [['<|startoftext|>', 'ask', 'and requirements', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'ask'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'ask', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10683683_0_1 [['<|startoftext|>', 'determine', 'or degree', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'determine'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'determine', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 1068686_4_1 [['<|startoftext|>', 're', 'and basin', ' in condition'], [0, 1, 10, 12]]
# l1: ['<|startoftext|>', 're'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 're', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10704107_1_3 [['<|startoftext|>', 'see', 'or shorts', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'see'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'see', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10708512_1_2 [['<|startoftext|>', 'plan', 'and behavior', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'plan'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'plan', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10708512_1_4 [['<|startoftext|>', 'try', 'or feedback', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'try'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'try', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10726944_2_3 [['<|startoftext|>', 'avoid', 'and alcohol', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'avoid'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'avoid', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 107339_0_7 [['<|startoftext|>', 'consider', 'and ring', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'consider'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'consider', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10740015_2_3 [['<|startoftext|>', 'ready', 'and check', '[PAD]'], [0, 2, -1]]
# l1: ['<|startoftext|>', 'ready'] l2: ['[PAD]', '[PAD]'] l3: [0, 2] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'ready', '[PAD]', '[PAD]'], [0, 2, -1, -1]]
#
# 1075033_0_1 [['<|startoftext|>', 'decide', 'or affair', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'decide'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'decide', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10753663_0_1 [['<|startoftext|>', 'have', 'or mucolytics', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'have'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'have', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10757281_0_0 [['<|startoftext|>', 'understand', 'and everything', ' with you with them'], [0, 1, 8, 9, 14, 15]]
# l1: ['<|startoftext|>', 'understand'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'understand', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10757281_3_5 [['<|startoftext|>', 'start', 'and behaviors', ' by parenting'], [0, 1, 9, 11]]
# l1: ['<|startoftext|>', 'start'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'start', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10758348_2_2 [['<|startoftext|>', 'avoid', 'and shoes', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'avoid'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'avoid', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10763344_0_7 [['<|startoftext|>', 'try', 'or remedy', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'try'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'try', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10778047_2_0 [['<|startoftext|>', 'avoid', 'or clothing', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'avoid'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'avoid', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 1078339_1_2 [['<|startoftext|>', 'span', 'distance', ' level or object with between marks'], [0, 9, 3, 1, 11, 12, 15]]
# l1: ['<|startoftext|>', 'span'] l2: ['[PAD]', '[PAD]'] l3: [0, 9] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'span', '[PAD]', '[PAD]'], [0, 9, -1, -1]]
#
# 1078339_2_2 [['<|startoftext|>', 'start', 'or tile', ' as point'], [0, 1, 14, 17]]
# l1: ['<|startoftext|>', 'start'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'start', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 1078870_1_2 [['<|startoftext|>', 'consider', 'or meaning', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'consider'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'consider', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 1079550_0_2 [['<|startoftext|>', 'items', 'or two', '[PAD]'], [0, 3, -1]]
# l1: ['<|startoftext|>', 'items'] l2: ['[PAD]', '[PAD]'] l3: [0, 3] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'items', '[PAD]', '[PAD]'], [0, 3, -1, -1]]
#
# 10799454_2_0 [['<|startoftext|>', 'avoid', 'and bindings', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'avoid'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'avoid', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10799483_2_2 [['<|startoftext|>', 'avoid', 'or towels', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'avoid'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'avoid', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10814966_2_0 [['<|startoftext|>', 'avoid', 'or someone', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'avoid'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'avoid', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10816947_0_3 [['<|startoftext|>', 'notice', 'or diarrhea', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'notice'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'notice', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 1082129_0_3 [['<|startoftext|>', 'consider', 'and furniture', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'consider'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'consider', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 1082129_3_5 [['<|startoftext|>', 'avoid', 'or yeast', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'avoid'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'avoid', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10823254_2_2 [['<|startoftext|>', 'avoid', 'and tea', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'avoid'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'avoid', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10836878_0_1 [['<|startoftext|>', 'wash', 'and cycle', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'wash'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'wash', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10847591_0_3 [['<|startoftext|>', 'track', 'or migraines', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'track'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'track', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10851219_0_1 [['<|startoftext|>', 'try', 'and silhouettes', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'try'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'try', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 1085868_0_2 [['<|startoftext|>', 'determine', 'or certification', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'determine'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'determine', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10867691_0_3 [['<|startoftext|>', 'meditate or use', 'and rate', '[PAD]'], [0, 1, 2, 3, -1]]
# l1: ['<|startoftext|>', 'meditate or use'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'meditate or use', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10895137_1_0 [['<|startoftext|>', 'stop', 'and bottles', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'stop'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'stop', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10910135_0_3 [['<|startoftext|>', 'avoid', 'or alcohol', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'avoid'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'avoid', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 109103_0_3 [['<|startoftext|>', 'note', 'or marks', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'note'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'note', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10925711_0_0 [['<|startoftext|>', 'avoid', 'and antacids', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'avoid'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'avoid', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10926992_1_3 [['<|startoftext|>', 'let', 'and soda', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'let'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'let', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10927396_0_3 [['<|startoftext|>', 'consider', 'and remorse', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'consider'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'consider', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 1093013_1_1 [['<|startoftext|>', 'determine', 'or certification', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'determine'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'determine', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10946180_2_0 [['<|startoftext|>', 'avoid', 'and cuts', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'avoid'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'avoid', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10946180_2_2 [['<|startoftext|>', 'avoid', 'and pants', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'avoid'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'avoid', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10952768_1_10 [['<|startoftext|>', 'click', 'or next', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'click'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'click', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10954623_1_7 [['<|startoftext|>', 'learn', 'and songs', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'learn'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'learn', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10963565_1_0 [['<|startoftext|>', 'stop', 'and eggs', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'stop'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'stop', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 1096932_1_0 [['<|startoftext|>', 'consider', 'and cover', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'consider'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'consider', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10974430_0_7 [['<|startoftext|>', 'try', 'and arousal', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'try'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'try', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 10977472_2_3 [['<|startoftext|>', 'avoid', 'or bandages', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'avoid'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'avoid', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 110037_0_3 [['<|startoftext|>', 'discuss', 'and departments', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'discuss'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'discuss', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11004063_0_2 [['<|startoftext|>', 'determine', 'and style', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'determine'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'determine', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11007_1_5 [['<|startoftext|>', 'learn', 'or condition', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'learn'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'learn', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11020361_1_1 [['<|startoftext|>', 'decide', 'or ira', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'decide'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'decide', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 1102042_1_1 [['<|startoftext|>', 'avoid but add', 'and degrees', '[PAD]'], [0, 1, 6, 7, -1]]
# l1: ['<|startoftext|>', 'avoid but add'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'avoid but add', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 1102142_1_3 [['<|startoftext|>', 'add', 'and butterplate', ' to left of forks'], [0, 9, 13, 14, 16, 17, 19]]
# l1: ['<|startoftext|>', 'add'] l2: ['[PAD]', '[PAD]'] l3: [0, 9] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'add', '[PAD]', '[PAD]'], [0, 9, -1, -1]]
#
# 1103301_2_5 [['<|startoftext|>', 'try', 'and schedules', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'try'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'try', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11033665_3_2 [['<|startoftext|>', 'avoid', 'or cleaners', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'avoid'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'avoid', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 1103465_1_5 [['<|startoftext|>', 'make', 'and enemies', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'make'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'make', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11049032_1_1 [['<|startoftext|>', 'prove', 'or documents', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'prove'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'prove', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 1106010_1_0 [['<|startoftext|>', 'look', 'or hay', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'look'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'look', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11070017_1_1 [['<|startoftext|>', 'let', 'and session', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'let'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'let', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 1107815_1_2 [['<|startoftext|>', 'alternate', 'and accuracy', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'alternate'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'alternate', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11111261_1_0 [['<|startoftext|>', 'try', 'and family', ' by tornado'], [0, 1, 8, 10]]
# l1: ['<|startoftext|>', 'try'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'try', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 1111191_1_2 [['<|startoftext|>', 'consider', 'or net', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'consider'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'consider', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11125365_1_2 [['<|startoftext|>', 'avoid', 'or salt', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'avoid'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'avoid', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11136484_1_1 [['<|startoftext|>', 'note', 'and restlessness', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'note'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'note', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11137934_2_2 [['<|startoftext|>', 'apply', 'or accelerators', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'apply'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'apply', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11138069_2_2 [['<|startoftext|>', 'let', 'and dents', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'let'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'let', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 1114459_0_6 [['<|startoftext|>', 'stop', 'and nausea', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'stop'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'stop', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11146_3_4 [['<|startoftext|>', 'learn', 'well ball', ' of foot'], [0, 1, 11, 13]]
# l1: ['<|startoftext|>', 'learn'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'learn', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 1115106_0_2 [['<|startoftext|>', 'steam', '[PAD]', ' cracks and crevices'], [0, 1, 6, -1]]
# l1: ['<|startoftext|>', 'steam'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'steam', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11155918_2_1 [['<|startoftext|>', 'decide', 'or master', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'decide'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'decide', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11163197_2_6 [['<|startoftext|>', 'wait', 'and stickers', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'wait'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'wait', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11182578_0_0 [['<|startoftext|>', 'determine', 'or threads', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'determine'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'determine', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 1118612_0_0 [['<|startoftext|>', 'encourage', 'and fluids', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'encourage'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'encourage', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11205902_2_5 [['<|startoftext|>', 'practice', 'and paperwork', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'practice'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'practice', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11206106_1_0 [['<|startoftext|>', 'consider', 'or vomiting', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'consider'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'consider', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11212441_0_1 [['<|startoftext|>', 'determine', 'or test', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'determine'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'determine', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11224154_1_1 [['<|startoftext|>', 'hire', 'or items', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'hire'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'hire', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11227180_0_0 [['<|startoftext|>', 'practice', 'and triangles', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'practice'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'practice', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11242960_0_2 [['<|startoftext|>', 'paint', 'and textures', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'paint'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'paint', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11250518_1_2 [['<|startoftext|>', 'discuss', 'or habits', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'discuss'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'discuss', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11259482_1_4 [['<|startoftext|>', 'make', 'or face', ' of clock'], [0, 1, 13, 15]]
# l1: ['<|startoftext|>', 'make'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'make', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11264199_1_0 [['<|startoftext|>', 'register', 'or id', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'register'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'register', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11265643_0_5 [['<|startoftext|>', 'stop and cut', 'or steroids', '[PAD]'], [0, 1, 9, 10, -1]]
# l1: ['<|startoftext|>', 'stop and cut'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'stop and cut', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 1127331_2_5 [['<|startoftext|>', 'run and estimate', 'or channelsit  and size', ' in it through sieve of fragments'], [0, 11, 19, 20, 8, 6, 7, 9, 12, 23, 24, 13, 18, 25, 28]]
# l1: ['<|startoftext|>', 'run and estimate'] l2: ['[PAD]', '[PAD]'] l3: [0, 11] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'run and estimate', '[PAD]', '[PAD]'], [0, 11, -1, -1]]
#
# 11279844_1_2 [['<|startoftext|>', 'try', 'or sounds', ' into head'], [0, 1, 11, 13]]
# l1: ['<|startoftext|>', 'try'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'try', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11291546_1_2 [['<|startoftext|>', 'tap', 'or payment', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'tap'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'tap', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11292201_1_0 [['<|startoftext|>', 'register', 'or id', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'register'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'register', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11292201_1_2 [['<|startoftext|>', 're', 'or party', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 're'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 're', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11292267_1_3 [['<|startoftext|>', 'avoid', 'and perms', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'avoid'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'avoid', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11292785_1_0 [['<|startoftext|>', 'register', 'or id', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'register'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'register', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11292785_1_4 [['<|startoftext|>', 're', 'or party', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 're'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 're', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11330181_2_1 [['<|startoftext|>', 'avoid', 'or food', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'avoid'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'avoid', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11340444_1_6 [['<|startoftext|>', 'get and dry', '[PAD]', ' shower or bath with towel'], [0, 1, 8, 9, 5, -1, 11, 14]]
# l1: ['<|startoftext|>', 'get and dry'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'get and dry', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 1134156_0_1 [['<|startoftext|>', 'make', 'and license', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'make'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'make', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11342353_1_0 [['<|startoftext|>', 'accept', 'and reactions', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'accept'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'accept', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11344576_1_0 [['<|startoftext|>', 'make', 'and items', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'make'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'make', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 1135950_1_8 [['<|startoftext|>', 'ask', 'or specialist', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'ask'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'ask', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11360502_0_3 [['<|startoftext|>', 'notice', 'or little', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'notice'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'notice', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 1136081_0_2 [['<|startoftext|>', 'make', 'or dress', '[PAD]'], [0, 11, -1]]
# l1: ['<|startoftext|>', 'make'] l2: ['[PAD]', '[PAD]'] l3: [0, 11] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'make', '[PAD]', '[PAD]'], [0, 11, -1, -1]]
#
# 11362944_0_1 [['<|startoftext|>', 'avoid', 'and shoes', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'avoid'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'avoid', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11371673_2_1 [['<|startoftext|>', 'avoid', 'or pain', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'avoid'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'avoid', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11371673_2_2 [['<|startoftext|>', 'exercise', 'or fever', '[PAD]'], [0, 3, -1]]
# l1: ['<|startoftext|>', 'exercise'] l2: ['[PAD]', '[PAD]'] l3: [0, 3] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'exercise', '[PAD]', '[PAD]'], [0, 3, -1, -1]]
#
# 11371837_1_3 [['<|startoftext|>', 'avoid', 'or damage', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'avoid'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'avoid', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11377481_0_2 [['<|startoftext|>', 'avoid', 'or condoms', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'avoid'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'avoid', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11377512_2_3 [['<|startoftext|>', 'avoid', 'or breastmilk', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'avoid'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'avoid', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11380433_1_5 [['<|startoftext|>', 'avoid', 'or websites', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'avoid'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'avoid', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11380635_1_0 [['<|startoftext|>', 'room', 'and flour', '[PAD]'], [0, 2, -1]]
# l1: ['<|startoftext|>', 'room'] l2: ['[PAD]', '[PAD]'] l3: [0, 2] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'room', '[PAD]', '[PAD]'], [0, 2, -1, -1]]
#
# 11385246_1_0 [['<|startoftext|>', 'consider', 'or allergies', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'consider'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'consider', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11399884_1_2 [['<|startoftext|>', 'try', 'or prayer', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'try'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'try', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11405174_0_5 [['<|startoftext|>', 'avoid', 'and irritation', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'avoid'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'avoid', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 1141229_2_0 [['<|startoftext|>', 'know', 'and emails', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'know'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'know', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11429575_0_2 [['<|startoftext|>', 'practice', 'and software', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'practice'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'practice', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11435700_1_0 [['<|startoftext|>', 'avoid', 'or showers', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'avoid'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'avoid', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11453544_0_0 [['<|startoftext|>', 'keep', 'and angles', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'keep'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'keep', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11453544_0_2 [['<|startoftext|>', 'stand', 'or landscape', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'stand'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'stand', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 1146273_0_0 [['<|startoftext|>', 'decide', 'or cpa', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'decide'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'decide', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11465768_1_4 [['<|startoftext|>', 'avoid', 'or alcohol', ' with emotions'], [0, 1, 8, 10]]
# l1: ['<|startoftext|>', 'avoid'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'avoid', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11466001_0_3 [['<|startoftext|>', 'have', 'or tiaras', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'have'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'have', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11474002_1_0 [['<|startoftext|>', 'stop', 'and baby', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'stop'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'stop', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11475389_1_0 [['<|startoftext|>', 'try', 'or drops', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'try'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'try', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 1147807_2_5 [['<|startoftext|>', 'wait', 'and covers', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'wait'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'wait', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11485940_0_1 [['<|startoftext|>', 'show', 'or pay', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'show'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'show', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11488048_2_5 [['<|startoftext|>', 'avoid', 'and items', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'avoid'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'avoid', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 1149034_0_5 [['<|startoftext|>', 'click', 'or disc', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'click'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'click', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11498509_1_5 [['<|startoftext|>', 'select', 'or batch', ' of checks'], [0, 1, 9, 10]]
# l1: ['<|startoftext|>', 'select'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'select', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11506871_0_3 [['<|startoftext|>', 'see', 'or number', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'see'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'see', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 1152624_4_1 [['<|startoftext|>', 'opposite', '[PAD]', " cows and heifers steers in of bull's"], [0, 17, 2, 9, -1, 1, 18, 20]]
# l1: ['<|startoftext|>', 'opposite'] l2: ['[PAD]', '[PAD]'] l3: [0, 17] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'opposite', '[PAD]', '[PAD]'], [0, 17, -1, -1]]
#
# 11540093_4_6 [['<|startoftext|>', 'consider', 'or school', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'consider'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'consider', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11546017_2_4 [['<|startoftext|>', 'stop', 'or difficulty', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'stop'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'stop', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 1155205_0_5 [['<|startoftext|>', 'consider', 'or perch', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'consider'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'consider', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 11554610_0_0 [['<|startoftext|>', 'decide', 'or journal', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'decide'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# ...
# AFTER: 1 [['<|startoftext|>', 'avoid', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 9517535_1_0 [['<|startoftext|>', 'use', 'or problem', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'use'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'use', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 9523521_1_4 [['<|startoftext|>', 'consider', 'and rutin', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'consider'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'consider', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 9534601_0_8 [['<|startoftext|>', 'avoid', 'or pollution', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'avoid'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'avoid', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 9536395_0_5 [['<|startoftext|>', 'practice', 'and values', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'practice'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'practice', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 9542613_2_1 [['<|startoftext|>', 'have', 'and rebuttals', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'have'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'have', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 955197_0_2 [['<|startoftext|>', 'decide', 'and being', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'decide'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'decide', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 9553830_2_0 [['<|startoftext|>', 'allow', 'and skull', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'allow'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'allow', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 9572263_0_3 [['<|startoftext|>', 'find', 'or articles', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'find'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'find', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 9574511_0_7 [['<|startoftext|>', 'avoid', 'and pears', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'avoid'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'avoid', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 9577043_2_3 [['<|startoftext|>', 'wait', 'or shower', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'wait'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'wait', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 9587601_3_4 [['<|startoftext|>', 're', 'or address', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 're'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 're', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 9590921_0_3 [['<|startoftext|>', 'vegetables', 'and textures', '[PAD]'], [0, 2, -1]]
# l1: ['<|startoftext|>', 'vegetables'] l2: ['[PAD]', '[PAD]'] l3: [0, 2] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'vegetables', '[PAD]', '[PAD]'], [0, 2, -1, -1]]
#
# 9599787_1_2 [['<|startoftext|>', 'continue', 'and tubes', ' one'], [0, 1, 9]]
# l1: ['<|startoftext|>', 'continue'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'continue', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 9602392_1_2 [['<|startoftext|>', 'have', 'or abnormalities', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'have'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'have', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 9609817_1_4 [['<|startoftext|>', 'learn', 'and saturation', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'learn'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'learn', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 961590_1_2 [['<|startoftext|>', 'keep', 'and sugar', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'keep'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'keep', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 9625438_0_2 [['<|startoftext|>', 'try', 'and igniter', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'try'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'try', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 96257_1_1 [['<|startoftext|>', 'avoid', 'or baths', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'avoid'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'avoid', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 9627674_0_4 [['<|startoftext|>', 'identify', 'or brackets', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'identify'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'identify', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 9632182_1_3 [['<|startoftext|>', 'notice', 'or flow', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'notice'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'notice', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 9636598_0_0 [['<|startoftext|>', 'decide', 'or perennials', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'decide'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'decide', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 9641342_1_1 [['<|startoftext|>', 'help', 'or therapy', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'help'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'help', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 9650363_3_2 [['<|startoftext|>', 'mark', 'and level', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'mark'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'mark', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 9651373_1_0 [['<|startoftext|>', 'decide', 'or pullets', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'decide'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'decide', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 9651492_1_1 [['<|startoftext|>', 'stop', 'or sensitivity', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'stop'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'stop', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 9656810_0_6 [['<|startoftext|>', 'repeat', 'and arms', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'repeat'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'repeat', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 966325_4_0 [['<|startoftext|>', 'call or visit', 'or family', '[PAD]'], [0, 1, 3, 4, -1]]
# l1: ['<|startoftext|>', 'call or visit'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'call or visit', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 9668898_0_0 [['<|startoftext|>', 'explain', 'and expenses', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'explain'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'explain', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 9680501_1_0 [['<|startoftext|>', 'meditate', 'and anxiety', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'meditate'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'meditate', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 9693627_1_2 [['<|startoftext|>', 'note', 'or signs', ' of abuse'], [0, 1, 10, 11]]
# l1: ['<|startoftext|>', 'note'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'note', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 9694290_0_1 [['<|startoftext|>', 'avoid', 'or eyes', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'avoid'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'avoid', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 9699263_1_5 [['<|startoftext|>', 'wait', 'and mmsi', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'wait'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'wait', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 9703534_0_3 [['<|startoftext|>', 'avoid', 'or liquids', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'avoid'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'avoid', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 9703534_2_2 [['<|startoftext|>', 'stop', 'or irritation', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'stop'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'stop', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 9708886_0_2 [['<|startoftext|>', 'notice', 'or instructions', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'notice'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'notice', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 9708886_1_0 [['<|startoftext|>', 'confirm', 'or disabilities', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'confirm'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'confirm', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 9710940_2_2 [['<|startoftext|>', 'explore', 'and pain', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'explore'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'explore', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 9713499_0_0 [['<|startoftext|>', 'learn', 'or language', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'learn'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'learn', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 9725034_0_3 [['<|startoftext|>', 'wait', 'or buttons', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'wait'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'wait', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 973357_0_3 [['<|startoftext|>', 'ask', 'or tampon', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'ask'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'ask', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 9753576_0_0 [['<|startoftext|>', 'check', 'or restrictions', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'check'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'check', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 976776_2_1 [['<|startoftext|>', 'slow and take', 'or rushing', '[PAD]'], [0, 1, 3, 4, -1]]
# l1: ['<|startoftext|>', 'slow and take'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'slow and take', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 9770160_0_1 [['<|startoftext|>', 'explain', 'or program', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'explain'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'explain', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 9784666_0_6 [['<|startoftext|>', 'surf', 'and information', '[PAD]'], [0, 3, -1]]
# l1: ['<|startoftext|>', 'surf'] l2: ['[PAD]', '[PAD]'] l3: [0, 3] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'surf', '[PAD]', '[PAD]'], [0, 3, -1, -1]]
#
# 9786685_2_2 [['<|startoftext|>', 'see', 'and love', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'see'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'see', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 9791043_3_4 [['<|startoftext|>', 'practice', 'and electronics', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'practice'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'practice', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 9799855_2_0 [['<|startoftext|>', 'have', 'and culture', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'have'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'have', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 9809106_3_0 [['<|startoftext|>', 'practice', 'and scales', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'practice'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'practice', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 9823881_0_0 [['<|startoftext|>', 'use', 'and effect', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'use'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'use', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 9841450_1_1 [['<|startoftext|>', 'paint', 'and roller', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'paint'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'paint', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 9844994_1_3 [['<|startoftext|>', 'have', 'and games', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'have'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'have', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 9860450_1_1 [['<|startoftext|>', 'select', 'or scores', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'select'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'select', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 9864957_1_2 [['<|startoftext|>', 'pick', 'door', ' efficiency and security for without window'], [0, 7, 3, 1, 9, 10, 12]]
# l1: ['<|startoftext|>', 'pick'] l2: ['[PAD]', '[PAD]'] l3: [0, 7] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'pick', '[PAD]', '[PAD]'], [0, 7, -1, -1]]
#
# 9869935_0_4 [['<|startoftext|>', 'avoid', 'or swelling', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'avoid'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'avoid', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 98758_3_3 [['<|startoftext|>', 'know', 'or physician', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'know'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'know', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 988399_2_1 [['<|startoftext|>', 'keep', 'and fluids', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'keep'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'keep', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 9887427_0_3 [['<|startoftext|>', 'encourage', 'and equipment', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'encourage'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'encourage', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 989215_2_2 [['<|startoftext|>', 'consider', 'or cart', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'consider'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'consider', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 9916385_1_1 [['<|startoftext|>', 'listen', 'and regulations', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'listen'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'listen', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 9917443_1_6 [['<|startoftext|>', 'encourage', 'and camps', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'encourage'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'encourage', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 991870_1_3 [['<|startoftext|>', 'make', 'and gadgets', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'make'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'make', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 9937037_1_2 [['<|startoftext|>', 'plan', 'or transportation', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'plan'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'plan', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 99411_1_1 [['<|startoftext|>', 'time', 'and seasoning', ' on masa'], [0, 13, 16, 18]]
# l1: ['<|startoftext|>', 'time'] l2: ['[PAD]', '[PAD]'] l3: [0, 13] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'time', '[PAD]', '[PAD]'], [0, 13, -1, -1]]
#
# 9962971_0_0 [['<|startoftext|>', 'measure', 'and length', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'measure'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'measure', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 9968422_0_0 [['<|startoftext|>', 'find', 'or service', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'find'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'find', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 9979819_0_0 [['<|startoftext|>', 'accept', 'and desires', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'accept'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'accept', '[PAD]', '[PAD]'], [0, 1, -1, -1]]
#
# 9982500_2_2 [['<|startoftext|>', 'avoid', 'or rot', '[PAD]'], [0, 1, -1]]
# l1: ['<|startoftext|>', 'avoid'] l2: ['[PAD]', '[PAD]'] l3: [0, 1] l4: [-1, -1]
# AFTER: 1 [['<|startoftext|>', 'avoid', '[PAD]', '[PAD]'], [0, 1, -1, -1]]

# %%
print(sid2step['10044817_0_6'])
print(sid2quadruple['10044817_0_6'])
# Out:
# ('pack', 'lightly', 'but', 'do', 'n’t', 'forget', 'your', 'rain', 'gear', 'and', 'layers', '.')
# [['<|startoftext|>', 'pack but forget', '[PAD]', '[PAD]'], [0, 1, -1, -1]]

# %%
# for i, values in list(sid2quadruple.items())[:100]:
#     if len(values[0]) < len(values[1]):
#         print("BEFORE:", i, values)
#         values[0][-2] = '[PAD]'
#         values[1] += [[-1]]
#         print("AFTER:", i, values, '\n')
# Out:
# BEFORE: 10000798_0_1 [['<|startoftext|>', 'ensure', '[PAD]', ' on back of door'], [[0], [1], [-1], [6, 8], [9, 12]]]
# AFTER: 10000798_0_1 [['<|startoftext|>', 'ensure', '[PAD]', ' on back of door'], [[0], [1], [-1], [6, 8], [9, 12], [-1]]]
#
# BEFORE: 10000798_0_2 [['<|startoftext|>', 'buy', 'hanger', ' with for hooks board with base'], [[0], [1], [3], [4], [7, 6, 9], [10, 15]]]
# AFTER: 10000798_0_2 [['<|startoftext|>', 'buy', '[PAD]', ' with for hooks board with base'], [[0], [1], [3], [4], [7, 6, 9], [10, 15], [-1]]]
#
# BEFORE: 10000798_0_3 [['<|startoftext|>', 'choose', 'hooks', ' for board with base'], [[0], [1], [3], [4, 6], [7, 12]]]
# AFTER: 10000798_0_3 [['<|startoftext|>', 'choose', '[PAD]', ' for board with base'], [[0], [1], [3], [4, 6], [7, 12], [-1]]]
#
# BEFORE: 10000832_0_2 [['<|startoftext|>', 'fill', 'inches', ' with of pot peanuts or gravel'], [[0], [1], [7], [11], [8, 10, 14, 15, 16]]]
# AFTER: 10000832_0_2 [['<|startoftext|>', 'fill', '[PAD]', ' with of pot peanuts or gravel'], [[0], [1], [7], [11], [8, 10, 14, 15, 16], [-1]]]
#
# BEFORE: 10000832_0_3 [['<|startoftext|>', 'pour', 'some', ' into of mix pot'], [[0], [1], [2], [7], [3, 6, 9]]]
# AFTER: 10000832_0_3 [['<|startoftext|>', 'pour', '[PAD]', ' into of mix pot'], [[0], [1], [2], [7], [3, 6, 9], [-1]]]
#
# BEFORE: 10000832_1_1 [['<|startoftext|>', 'place', 'plant', ' in center of pot'], [[0], [1], [4], [5, 7], [8, 10]]]
# AFTER: 10000832_1_1 [['<|startoftext|>', 'place', '[PAD]', ' in center of pot'], [[0], [1], [4], [5, 7], [8, 10], [-1]]]
#
# BEFORE: 10000832_1_2 [['<|startoftext|>', 'fill', 'rest', ' with of pot mix'], [[0], [1], [3], [7], [4, 6, 10]]]
# AFTER: 10000832_1_2 [['<|startoftext|>', 'fill', '[PAD]', ' with of pot mix'], [[0], [1], [3], [7], [4, 6, 10], [-1]]]
#
# BEFORE: 10000832_2_2 [['<|startoftext|>', 'store', 'plants', ' in during garage winter'], [[0], [1], [5], [6], [11, 8, 13]]]
# AFTER: 10000832_2_2 [['<|startoftext|>', 'store', '[PAD]', ' in during garage winter'], [[0], [1], [5], [6], [11, 8, 13], [-1]]]
#
# BEFORE: 10002000_1_0 [['<|startoftext|>', 'talk', '[PAD]', ' to in student private'], [[0], [1], [-1], [2], [5, 4, 6]]]
# AFTER: 10002000_1_0 [['<|startoftext|>', 'talk', '[PAD]', ' to in student private'], [[0], [1], [-1], [2], [5, 4, 6], [-1]]]
#
# BEFORE: 10002000_1_1 [['<|startoftext|>', 'ask', 'student', ' for suggestions on'], [[0], [1], [3], [4, 5], [6]]]
# AFTER: 10002000_1_1 [['<|startoftext|>', 'ask', '[PAD]', ' for suggestions on'], [[0], [1], [3], [4, 5], [6], [-1]]]
#
# BEFORE: 10002000_2_1 [['<|startoftext|>', 'meet', 'students', ' at before door class'], [[0], [1], [3], [4], [9, 6, 10]]]
# AFTER: 10002000_2_1 [['<|startoftext|>', 'meet', '[PAD]', ' at before door class'], [[0], [1], [3], [4], [9, 6, 10], [-1]]]
#
# BEFORE: 1000266_0_4 [['<|startoftext|>', 'stay', '[PAD]', ' from toys for children'], [[0], [1], [-1], [3, 4], [6, 7]]]
# AFTER: 1000266_0_4 [['<|startoftext|>', 'stay', '[PAD]', ' from toys for children'], [[0], [1], [-1], [3, 4], [6, 7], [-1]]]
#
# BEFORE: 1000266_0_6 [['<|startoftext|>', 'check', '[PAD]', ' with about vet rawhide'], [[0], [1], [-1], [2], [5, 4, 6]]]
# AFTER: 1000266_0_6 [['<|startoftext|>', 'check', '[PAD]', ' with about vet rawhide'], [[0], [1], [-1], [2], [5, 4, 6], [-1]]]
#
# BEFORE: 1000266_0_7 [['<|startoftext|>', 'keep', 'dog', ' from items in home'], [[0], [1], [3], [5, 7], [8, 10]]]
# AFTER: 1000266_0_7 [['<|startoftext|>', 'keep', '[PAD]', ' from items in home'], [[0], [1], [3], [5, 7], [8, 10], [-1]]]
#
# BEFORE: 10004257_0_1 [['<|startoftext|>', 'include', 'information', ' in about sale body of ad'], [[0], [1], [4], [8], [5, 7, 10], [11, 13]]]
# AFTER: 10004257_0_1 [['<|startoftext|>', 'include', '[PAD]', ' in about sale body of ad'], [[0], [1], [4], [8], [5, 7, 10], [11, 13], [-1]]]
#
# BEFORE: 10004257_0_2 [['<|startoftext|>', 'list', 'examples', ' of some of items'], [[0], [1], [2], [3, 4], [5, 7]]]
# AFTER: 10004257_0_2 [['<|startoftext|>', 'list', '[PAD]', ' of some of items'], [[0], [1], [2], [3, 4], [5, 7], [-1]]]
#
# BEFORE: 10004257_0_3 [['<|startoftext|>', 'include', 'pictures', ' of some of items'], [[0], [1], [2], [3, 4], [5, 8]]]
# AFTER: 10004257_0_3 [['<|startoftext|>', 'include', '[PAD]', ' of some of items'], [[0], [1], [2], [3, 4], [5, 8], [-1]]]
#
# BEFORE: 10004257_1_2 [['<|startoftext|>', 'post', '[PAD]', ' about on sale accounts'], [[0], [1], [-1], [2], [5, 4, 10]]]
# AFTER: 10004257_1_2 [['<|startoftext|>', 'post', '[PAD]', ' about on sale accounts'], [[0], [1], [-1], [2], [5, 4, 10], [-1]]]
#
# BEFORE: 10004257_1_3 [['<|startoftext|>', 'send', 'email', ' to all of contacts'], [[0], [1], [3], [4, 5], [6, 8]]]
# AFTER: 10004257_1_3 [['<|startoftext|>', 'send', '[PAD]', ' to all of contacts'], [[0], [1], [3], [4, 5], [6, 8], [-1]]]
#
# BEFORE: 1000430_0_3 [['<|startoftext|>', 'come', '[PAD]', ' with strategy for business'], [[0], [1], [-1], [3, 6], [7, 9]]]
# AFTER: 1000430_0_3 [['<|startoftext|>', 'come', '[PAD]', ' with strategy for business'], [[0], [1], [-1], [3, 6], [7, 9], [-1]]]
#
# BEFORE: 1000430_1_6 [['<|startoftext|>', 'set', 'system', ' with of sale tablet'], [[0], [1], [10], [11], [8, 9, 13]]]
# AFTER: 1000430_1_6 [['<|startoftext|>', 'set', '[PAD]', ' with of sale tablet'], [[0], [1], [10], [11], [8, 9, 13], [-1]]]
#
# BEFORE: 1000430_2_0 [['<|startoftext|>', 'look', '[PAD]', ' for areas with lots of traffic'], [[0], [1], [-1], [2, 3], [4, 5], [6, 8]]]
# AFTER: 1000430_2_0 [['<|startoftext|>', 'look', '[PAD]', ' for areas with lots of traffic'], [[0], [1], [-1], [2, 3], [4, 5], [6, 8], [-1]]]

# %%
# # Write file.
# with open("sid2quadruple.p", "wb") as file:
#     pickle.dump(sid2quadruple, file)
